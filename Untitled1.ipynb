# %%
#! /usr/bin/env python
# -*- coding: utf-8 -*-

import requests
import json
import pymongo
import pandas
import re
import nltk
import numpy
import itertools
import datetime 


from ggplot import *
from matplotlib import pyplot as plt
from wordcloud import WordCloud
from pymongo import MongoClient
from requests_oauthlib import OAuth2
from tqdm import tqdm

from watson_developer_cloud import NaturalLanguageUnderstandingV1
from watson_developer_cloud.natural_language_understanding_v1 \
  import Features, EntitiesOptions, KeywordsOptions

#Base de datos 
client = MongoClient('localhost:27017')
db = client.db_analyzer
db_analyzer = db.analyzer
collection_posts = db_analyzer.posts
collection_comments = db_analyzer.comments
# Out:
# d:\python\lib\site-packages\ggplot\utils.py:81: FutureWarning: pandas.tslib is deprecated and will be removed in a future version.
# You can access Timestamp as pandas.Timestamp
#   pd.tslib.Timestamp,
# d:\python\lib\site-packages\ggplot\stats\smoothers.py:4: FutureWarning: The pandas.lib module is deprecated and will be removed in a future version. These are private functions and can be accessed from pandas._libs.lib instead
#   from pandas.lib import Timestamp
# d:\python\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
#Limpiamos la base de datos para que no se repliquen los datos o interfieran con los de otras páginas
collection_posts.delete_many({})
collection_comments.delete_many({})

# %%
id = "tenerifevacanze"              # id de la página que va a ser analizada
"""Páginas usadas
 * tenerifevacanze
 * VisitTenerifeES"""



url = 'https://graph.facebook.com/v2.12/'
page_url = 'https://graph.facebook.com/v2.12/%s/feed?fields=id,message,reactions,shares,from,caption,created_time,likes.summary(true)' %id
print(page_url)
# Todos los campos deben de ser especificados
comments_url = 'https://graph.facebook.com/v2.12/{post_id}/comments?filter=stream&limit=100'

# Variable con el token de acceso de Facebook
params = {'access_token' : 'EAACQFfa9JeIBAI1wRhKxGmFTvH5BJ6GhmhrrPrWkvkh0iG29oiSGPocYWgxIYaDgkFapkxmn4ZB7bz0nVb6D0DQ2VynIZAT7gegZCkixBaXlcRZBvpCfArZB0Yfyr3HRUUJ3Epc4CJHsgNRnmlqQZCRt5QCDzU7ioZD'}
posts = requests.get(page_url, params = params)
posts = posts.json()
print(posts)
# Out:
# https://graph.facebook.com/v2.12/tenerifevacanze/feed?fields=id,message,reactions,shares,from,caption,created_time,likes.summary(true)
# {'data': [{'id': '145257262182078_1969363736438079', 'message': 'cancion ganadora en el primer FESTIVAL DEL ATLANTICO  EN PUERTO DE LA CRUZ... CANTA  FRANCISCO GALIAN', 'caption': 'youtube.com', 'created_time': '2018-05-16T18:08:43+0000', 'likes': {'data': [], 'summary': {'total_count': 0, 'can_like': True, 'has_liked': False}}}, {'id': '145257262182078_1967009003340219', 'message': 'Con el corazón roto. El Sobradillo y los barrios del Distrito Suroeste. Comparto y les solicito ayuda para que puedan hacer un juicio del mismo, es muy preocupante la situación de estos barrios de la capital en los aspectos educativos y sociales...\n\n', 'caption': 'emociones.eu', 'created_time': '2018-05-14T19:41:03+0000', 'likes': {'data': [], 'paging': {'cursors': {'before': 'NzM3MzMxNDM2NDY2Mzg5', 'after': 'NzM3MzMxNDM2NDY2Mzg5'}}, 'summary': {'total_count': 1, 'can_like': True, 'has_liked': False}}}, {'id': '145257262182078_1966527473388372', 'message': '#CRYOTOBAR un espacio que ofrece el ambiente ideal para hablar de negocios, acompañados siempre de una excelente oferta de comidas y bebidas.\n#cryptobar #loscritianos #tenerife #criptomonedas #cryptocurrency #beer #pizza #business #blockchain', 'created_time': '2018-05-14T11:30:53+0000', 'likes': {'data': [], 'paging': {'cursors': {'before': 'NzM3MzMxNDM2NDY2Mzg5', 'after': 'NzM3MzMxNDM2NDY2Mzg5'}}, 'summary': {'total_count': 1, 'can_like': True, 'has_liked': False}}}, {'id': '145257262182078_1966489106725542', 'message': 'WIN WIN WIN! 🌞\nFirst there was scuba diving....and then there was BOB Diving! All the underwater fun of traditional scuba diving, with much less effort! The underwater scooter! \U0001f92d\n\nFOR YOUR CHANCE TO WIN 2 TICKETS: \n1. FILL IN THE FORM HERE: www.tenerifetickets.com/competitions\n\nIts as simple as that! This prize is worth €120 and is for anyone over the age of 10 years!', 'caption': 'tenerifetickets.com', 'created_time': '2018-05-14T10:42:42+0000', 'likes': {'data': [], 'summary': {'total_count': 0, 'can_like': True, 'has_liked': False}}}, {'id': '145257262182078_1964265323614587', 'message': 'Que bonita ciudad me encanta tenerife', 'created_time': '2018-05-12T17:43:33+0000', 'likes': {'data': [], 'summary': {'total_count': 0, 'can_like': True, 'has_liked': False}}}, {'id': '145257262182078_1963895200318266', 'message': 'Próximamente compra en Tenerife artículos diferentes y a buen precio\nhttps://www.facebook.com/groups/mirinconentenerife/', 'created_time': '2018-05-12T11:55:27+0000', 'likes': {'data': [], 'paging': {'cursors': {'before': 'NjQ1MDkzODE1ODgyNzE3', 'after': 'NjQ1MDkzODE1ODgyNzE3'}}, 'summary': {'total_count': 1, 'can_like': True, 'has_liked': False}}}, {'id': '145257262182078_1958551770852609', 'shares': {'count': 43}, 'from': {'name': 'Tenerife', 'id': '145257262182078'}, 'caption': 'vimeo.com', 'created_time': '2018-05-08T09:27:35+0000', 'likes': {'data': [], 'paging': {'cursors': {'before': 'MTcxMjE5NzQ4MjE2MTg0MwZDZD', 'after': 'NzU2MTQ0Nzg3OTE0OTU5'}, 'next': 'https://graph.facebook.com/v2.12/145257262182078_1958551770852609/likes?access_token=EAACQFfa9JeIBAI1wRhKxGmFTvH5BJ6GhmhrrPrWkvkh0iG29oiSGPocYWgxIYaDgkFapkxmn4ZB7bz0nVb6D0DQ2VynIZAT7gegZCkixBaXlcRZBvpCfArZB0Yfyr3HRUUJ3Epc4CJHsgNRnmlqQZCRt5QCDzU7ioZD&summary=true&limit=25&after=NzU2MTQ0Nzg3OTE0OTU5'}, 'summary': {'total_count': 171, 'can_like': True, 'has_liked': False}}}, {'id': '145257262182078_1953665701341216', 'message': 'Tenerife Forest, Canary Islands, Spain\n.\nBy -> Grafixart_photo\nFacebook : Grafixart Sam\nInstagram : Grafixart_photo\n.\n#landscape #mountain #photo #reflection #europe #grafixartphoto #spain', 'created_time': '2018-05-04T16:02:37+0000', 'likes': {'data': [], 'paging': {'cursors': {'before': 'NzM3MzMxNDM2NDY2Mzg5', 'after': 'NzM3MzMxNDM2NDY2Mzg5'}}, 'summary': {'total_count': 1, 'can_like': True, 'has_liked': False}}}, {'id': '145257262182078_1951869544854165', 'message': 'La Orotava', 'shares': {'count': 76}, 'from': {'name': 'Tenerife', 'id': '14525726218207 ...

# %%
# Data extraction

while True:
    try:
        print("Recopilando datos...")
        ### Recupera un post
        for element in posts['data']:
            collection_posts.insert_one(element)
            #### Recupera todos los comentarios de ese post
            this_comment_url = comments_url.replace("{post_id}", element['id'])
            comments = requests.get(this_comment_url, params = params).json()
            # Recorre todos los comentarios hasta que la respuesta esté vacía, que no haya más comentarios
            while ('paging' in comments and 'cursors' in comments['paging'] and 'after' in comments['paging']['cursors']):
                ### Itera a través de todos los comentarios
                for comment in comments['data']:
                    comment['post_id'] = element['id']
                    collection_comments.insert_one(comment)
                comments = requests.get(this_comment_url + '&after=' + comments['paging']['cursors']['after'], params = params).json()
        #### Vamos a la siguiente página en feed
        posts = requests.get(posts['paging']['next']).json()
    except KeyError as e:
        print(e)
        break

print("Datos recopilados")
# Out:
# Recopilando datos...
# Recopilando datos...
# Recopilando datos...
# Recopilando datos...
# Recopilando datos...
# Recopilando datos...
# Recopilando datos...
# Recopilando datos...
# Recopilando datos...
# Recopilando datos...
# Recopilando datos...
# Recopilando datos...
# Recopilando datos...
# Recopilando datos...
# Recopilando datos...
# Recopilando datos...
# Recopilando datos...
# Recopilando datos...
# Recopilando datos...
# Recopilando datos...
# Recopilando datos...
# Recopilando datos...
# Recopilando datos...
# Recopilando datos...
# Recopilando datos...
# Recopilando datos...
# Recopilando datos...
# Recopilando datos...
# Recopilando datos...
# Recopilando datos...
# Recopilando datos...
# Recopilando datos...
# Recopilando datos...
# Recopilando datos...
# Recopilando datos...
# Recopilando datos...
# Recopilando datos...
# Recopilando datos...
# Recopilando datos...
# Recopilando datos...
# 'next'
# Datos recopilados

# %%
# Data pull

posts_data = []
comments_data = []

for doc in collection_posts.find({}):
    if 'message' in doc.keys():
        posts_data.append((doc['message'], doc['created_time'], doc['likes']['summary']['total_count'], doc.get('shares', {'count': 0})['count'], doc['id']))
    else:
        pass
        #print("No message")
        
print(len(posts_data))
    
for comment in collection_comments.find({}):
    if 'message' in comment.keys():
        comments_data.append((comment['message'], comment['created_time'], comment['post_id']))
    else:
        pass

print(len(comments_data))
# Out:
# 819
# 6394

# %%
print(posts_data)
df_posts = pandas.DataFrame(posts_data)
df_posts.columns = ['message', 'created_time', 'likes', 'shares', 'post_id']
df_comments = pandas.DataFrame(comments_data)
df_comments.columns = ['message', 'created_time', 'post_id']
# Out:
# [('cancion ganadora en el primer FESTIVAL DEL ATLANTICO  EN PUERTO DE LA CRUZ... CANTA  FRANCISCO GALIAN', '2018-05-16T18:08:43+0000', 0, 0, '145257262182078_1969363736438079'), ('Con el corazón roto. El Sobradillo y los barrios del Distrito Suroeste. Comparto y les solicito ayuda para que puedan hacer un juicio del mismo, es muy preocupante la situación de estos barrios de la capital en los aspectos educativos y sociales...\n\n', '2018-05-14T19:41:03+0000', 1, 0, '145257262182078_1967009003340219'), ('#CRYOTOBAR un espacio que ofrece el ambiente ideal para hablar de negocios, acompañados siempre de una excelente oferta de comidas y bebidas.\n#cryptobar #loscritianos #tenerife #criptomonedas #cryptocurrency #beer #pizza #business #blockchain', '2018-05-14T11:30:53+0000', 1, 0, '145257262182078_1966527473388372'), ('WIN WIN WIN! 🌞\nFirst there was scuba diving....and then there was BOB Diving! All the underwater fun of traditional scuba diving, with much less effort! The underwater scooter! \U0001f92d\n\nFOR YOUR CHANCE TO WIN 2 TICKETS: \n1. FILL IN THE FORM HERE: www.tenerifetickets.com/competitions\n\nIts as simple as that! This prize is worth €120 and is for anyone over the age of 10 years!', '2018-05-14T10:42:42+0000', 0, 0, '145257262182078_1966489106725542'), ('Que bonita ciudad me encanta tenerife', '2018-05-12T17:43:33+0000', 0, 0, '145257262182078_1964265323614587'), ('Próximamente compra en Tenerife artículos diferentes y a buen precio\nhttps://www.facebook.com/groups/mirinconentenerife/', '2018-05-12T11:55:27+0000', 1, 0, '145257262182078_1963895200318266'), ('Tenerife Forest, Canary Islands, Spain\n.\nBy -> Grafixart_photo\nFacebook : Grafixart Sam\nInstagram : Grafixart_photo\n.\n#landscape #mountain #photo #reflection #europe #grafixartphoto #spain', '2018-05-04T16:02:37+0000', 1, 0, '145257262182078_1953665701341216'), ('La Orotava', '2018-05-03T09:59:00+0000', 588, 76, '145257262182078_1951869544854165'), ("come vivere l'isola al meglio!!! Monster BIKE elettrica....e goooo!!! 60km di autonomia!!!! goditi la tua vacanza!!!!passa da noi!!! provala GRATIS!!!\nti innamorerai!!! prodotto unico! non è solo una bicicletta elettrica....E' LA MONSTER BIKE!!!!!\n\nhow to live the island to the fullest !!! Monster BIKE electric .... and goooo !!! 60km of autonomy !!!! enjoy your holiday !!!! come to us !!! try it for FREE !!!\nyou will fall in love!!! unique product! it's not just an electric bike .... MONSTER BIKE!!!!\n\ncómo vivir la isla al máximo! Monster BIKE electric .... y goooo !!! 60km de autonomía !!!! disfrute sus vacaciones !!!! ven a nosotros !!! Pruébalo gratis !!!\n¡¡¡te vas a enamorar!!! producto único! no es solo una bicicleta eléctrica ... ¡¡¡ES LA BICI MONSTER !!!!!", '2018-04-28T17:38:48+0000', 1, 0, '145257262182078_1945939225447197'), ('En Los Cristianos, en el Centro Comercial Apolo, se encuentra nuestro CRYPTOBAR, un espacio donde puede usted saciar su sed con una caña bien fría, puede comerse una deliciosa pizza o puede hablar de negocios...siempre será una excelente opción para sus días y noches en Tenerife. Le esperamos. #cvryptobar #loscristianos #tenerife #LaMejorOpcion', '2018-04-28T11:06:45+0000', 2, 0, '145257262182078_1945520682155718'), ('Curso de Clown en Santa Cruz de Tenerife con Alex Navarro.\nUna experiencia extraordinaria y divertida. \nwww.cursosdeclown.com/tenerife\n\nOs comparto esto por si alguno de vuestros seguidores pudieran estar interesados.  Saludos.', '2018-04-24T19:20:33+0000', 1, 0, '145257262182078_1940838575957262'), ('Una nueva y excelente opción para los días y las noches en Tenerife...#cryptobar\nPizza, cócteles, tapas, cañas y momentos inolvidables.\nLos esperamos!!!', '2018-04-20T14:08:01+0000', 1, 0, '145257262182078_1935340723173714'), ("Admin please delete if not allowed.\nTenerife, one of the most beautiful Islands in Europe for brits to live or holiday and arguably the most popular of all 7 Canary Islands. Guys, if you are looking to come on holiday or you'r ...

# %%
# Feature extraction


# Funciones

# Limpia comentarios y posts
def preprocess(text):
    # Limpieza básica
    # Limpia de espacios y signos de puntuación, y convierte en minúscula
    text = text.strip()
    text = re.sub(r'[^\w\s]','',text)
    text = text.lower()

    # Divide en tokens
    tokens = nltk.word_tokenize(text) 

    return(tokens)

# Obtiene los hastags de los mensajes
def get_hashtags(text):
    hashtags = re.findall(r"#(\w+)", text)
    return(hashtags)

# 
def tag_tokens(preprocessed_tokens):
    pos = nltk.pos_tag(preprocessed_tokens)
    return(pos)

# 
def get_keywords(tagged_tokens, pos='all'):

    if(pos == 'all'):
        lst_pos = ('NN','JJ','VB')
    elif(pos == 'nouns'):
        lst_pos = 'NN'
    elif(pos == 'verbs'):
        lst_pos = 'VB'
    elif(pos == 'adjectives'):
        lst_pos = 'JJ'
    else:
        lst_pos = ('NN','JJ','VB')

    keywords = [tup[0] for tup in tagged_tokens if tup[1].startswith(lst_pos)]
    return(keywords)

def get_noun_phrases(tagged_tokens):

    grammar = "NP: {<DT>?<JJ>*<NN>}"
    cp = nltk.RegexpParser(grammar)
    tree = cp.parse(tagged_tokens)

    result = []
    for subtree in tree.subtrees(filter=lambda t: t.label() == 'NP'):
        #Solo tomamos frases, no palabras sueltas
        if(len(subtree.leaves()) > 1):
            outputs = [tup[0] for tup in subtree.leaves()]
            outputs = " ".join(outputs)
            result.append(outputs)
    return(result)

def execute_pipeline(dataframe):
    print("Entro execute pipeline")
    #Obtener hashtags
    dataframe['hashtags'] = dataframe.apply(lambda x: get_hashtags(x['message']), axis=1)
    print("Paso 1")
    #
    dataframe['preprocessed'] = dataframe.apply(lambda x: preprocess(x['message']), axis=1, reduce=True)
    print("Paso 2")
    #
    dataframe['tagged'] = dataframe.apply(lambda x: tag_tokens(x['preprocessed']), axis=1)
    print("Paso 3") 
    #Extraer palabras clave
    dataframe['keywords'] = dataframe.apply(lambda x: get_keywords(x['tagged'], 'all'), axis=1)
    print("Paso 4")
    #
    dataframe['noun_phrases'] = dataframe.apply(lambda x: get_noun_phrases(x['tagged']), axis=1)
    print("Paso 5")
    print("Salgo execute pipeline")
    return(dataframe)

# %%
df_posts = execute_pipeline(df_posts)
# Out:
# Entro execute pipeline
# Paso 1
# Paso 2
# Paso 3
# Paso 4
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Paso 5
# Salgo execute pipeline

# %%
df_comments = execute_pipeline(df_comments)
# Out:
# Entro execute pipeline
# Paso 1
# Paso 2
# Paso 3
# Paso 4
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Paso 5
# Salgo execute pipeline

# %%
#Content analysis
 
def viz_wordcloud(dataframe, column_name):
    lst_tokens = list(itertools.chain.from_iterable(dataframe[column_name]))
    lst_phrases = [phrase.replace(" ", "_") for phrase in lst_tokens]

    CLEANING_LIST = [] # Lista con palabras que consideraremos como ruido
    lst_phrases = [phrase.replace(" ","_") for phrase in lst_phrases if not any(spam in phrase.lower() for spam in CLEANING_LIST)] # Quitamos los keywords considerados como ruido
    lst_phrases = [phrase.replace(" ","_") for phrase in lst_phrases if len(phrase) > 1] # Eliminamos los tokens que son de una sola letra

    wordcloud = WordCloud(font_path='./Fonts/Verdana.ttf', background_color="White", max_words=2000, max_font_size=40, random_state=42).generate(" ".join(lst_phrases))

    plt.figure()
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.show()

def print_verbatims(df, nb_verbatim, keywords):
    verbatims = df[df['message'].str.contains(keywords)]
    for i, text in verbatims.head(nb_verbatim).iterrows():
        print(text['message'])

# %%
df_comments['date'] = df_comments['created_time'].apply(pandas.to_datetime)
df_comments_ts = df_comments.set_index(['date'])
df_comments_ts = df_comments_ts['2015-01-01':]

df_posts['date'] = df_posts['created_time'].apply(pandas.to_datetime)
df_posts_ts = df_posts.set_index(['date'])
df_posts_ts = df_posts_ts['2015-01-01':]

# %%
#Creamos un data frame que contiene la cantidad promedio de likes y shares por semana
dx = df_posts_ts.resample('W').mean()
dx.index.name = 'date'
dx = dx.reset_index()

#Mostramos el progreso de likes
p = ggplot(dx, aes(x = 'date', y = 'likes')) + geom_line()
p = p + xlab("Date") + ylab("Number of likes") + ggtitle("Facebook vacanzeTenerife Page")
print(p)

#Mostramos el progreso de shares
p = ggplot(dx, aes(x = 'date', y = 'shares')) + geom_line()
p = p + xlab("Date") + ylab("Number of shares") + ggtitle("Facebook VacanzeTenerife Page")
print(p)
# Out:
# <ggplot: (26049593)>
# <ggplot: (27164937)>

# %%
def max_wordcloud(ts_df_posts, ts_df_comments, columnname, criterium):
    mean_week = ts_df_posts.resample('W').mean()
    start_week = (mean_week[criterium].idxmax() - datetime.timedelta(days=7)).strftime('%Y-%m-%d')
    end_week = mean_week[criterium].idxmax().strftime('%Y-%m-%d')
    viz_wordcloud(ts_df_posts[start_week:end_week], columnname)
    viz_wordcloud(ts_df_comments[start_week:end_week], columnname)

# %%
url_api = "https://gateway.watsonplatform.net/natural-language-understanding/api"

def get_alchemy(text):
    natural_language_understanding = NaturalLanguageUnderstandingV1(
        username="209d9a26-cca5-4bef-9690-33f5e8ee66da",
        password="SpWglqCnrHqD",
        version='2018-03-16')

    response = natural_language_understanding.analyze(
        text=text,
        features=Features(
            emotion=EmotionOptions(),
            sentiment=SentimentOptions()))

    print(json.dumps(response, indent=2))

# %%
get_alchemy(df_comments['message'][2])
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 67,
#     "features": 2
#   },
#   "sentiment": {
#     "document": {
#       "score": 0.719416,
#       "label": "positive"
#     }
#   },
#   "language": "en",
#   "emotion": {
#     "document": {
#       "emotion": {
#         "sadness": 0.014019,
#         "joy": 0.606376,
#         "fear": 0.177395,
#         "disgust": 0.222445,
#         "anger": 0.05033
#       }
#     }
#   }
# }

# %%
from watson_developer_cloud import NaturalLanguageUnderstandingV1
from watson_developer_cloud.natural_language_understanding_v1 \
  import Features, EmotionOptions, SentimentOptions

# %%
def get_json(text):
    natural_language_understanding = NaturalLanguageUnderstandingV1(
        username="209d9a26-cca5-4bef-9690-33f5e8ee66da",
        password="SpWglqCnrHqD",
        version='2018-03-16')
    
    response = natural_language_understanding.analyze(
        text=text,
        features=Features(
            emotion=EmotionOptions(),
            sentiment=SentimentOptions()))

    return json.dumps(response, indent=2)

# %%
prueba = get_json(df_comments['message'][4])
# Out:
# ---------------------------------------------------------------------------
# WatsonApiException                        Traceback (most recent call last)
# <ipython-input-28-fec6fcfa4e6d> in <module>()
# ----> 1 prueba = get_json(df_comments['message'][4])
#
# <ipython-input-27-803fe9c94aad> in get_json(text)
#       9         features=Features(
#      10             emotion=EmotionOptions(),
# ---> 11             sentiment=SentimentOptions()))
#      12
#      13     return json.dumps(response, indent=2)
#
# d:\python\lib\site-packages\watson_developer_cloud\natural_language_understanding_v1.py in analyze(self, features, text, html, url, clean, xpath, fallback_to_raw, return_analyzed_text, language, limit_text_characters, **kwargs)
#     202             params=params,
#     203             json=data,
# --> 204             accept_json=True)
#     205         return response
#     206
#
# d:\python\lib\site-packages\watson_developer_cloud\watson_service.py in request(self, method, url, accept_json, headers, params, json, data, files, **kwargs)
#     446             error_info = self._get_error_info(response)
#     447             raise WatsonApiException(response.status_code, error_message,
# --> 448                                      info=error_info, httpResponse=response)
#
# WatsonApiException: Error: unsupported text language: pl, Code: 400 , X-dp-watson-tran-id: gateway02-254966697 , X-global-transaction-id: ffea405d5afd7db40f327ba9

# %%
print(prueba)
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 67,
#     "features": 2
#   },
#   "sentiment": {
#     "document": {
#       "score": 0.719415,
#       "label": "positive"
#     }
#   },
#   "language": "en",
#   "emotion": {
#     "document": {
#       "emotion": {
#         "sadness": 0.014019,
#         "joy": 0.606376,
#         "fear": 0.177395,
#         "disgust": 0.222445,
#         "anger": 0.05033
#       }
#     }
#   }
# }

# %%
prueba['sentiment']
# Out:
# {'document': {'score': 0.719416, 'label': 'positive'}}

# %%
prueba['sentiment']['document']['label']
# Out:
# 'positive'

# %%
def get(text):
    natural_language_understanding = NaturalLanguageUnderstandingV1(
        username="209d9a26-cca5-4bef-9690-33f5e8ee66da",
        password="SpWglqCnrHqD",
        version='2018-03-16')
    try:
        response = natural_language_understanding.analyze(
            text=text,
            features=Features(
                emotion=EmotionOptions(),
                sentiment=SentimentOptions()))

        fichero = json.dumps(response, indent=2)
        fichero = json.loads(fichero)

        lenguaje = fichero['language']
        if 'emotion' in fichero.keys():
            emotions = fichero['emotion']['document']['emotion']
        else:
            emotions = None
        sentiment = fichero['sentiment']['document']
        return (lenguaje, emotions, sentiment)
    except:
        return None

# %%
print(get(df_comments['message'][96]))
# Out:
# ('es', None, {'score': 0.566601, 'label': 'positive'})

# %%
alchemy = df_comments.head(200)
print(alchemy)
# Out:
#                                                message  \
# 0                                         Nerea Miñano
# 1                        Alejandra HLo Ángela Martínez
# 2    Joanna Wojnowska I think I need to visit you s...
# 3       Lea Ostrožnik Asija Šerifoski Zana Kunaver 😍😍😍
# 4                                      Lionel Wojcik 😍
# 5                                  Alistair Macfarlane
# 6                                          Renzo Fedri
# 7                               Ich liebe diese Insel❤
# 8                                  Aniello Intartaglia
# 9                   Wolfgang Czermak Our next project?
# 10   😍😍😍😍😍😍 straordinario, proprio i posti dove sia...
# 11                              Te amo, Tenerife . :-*
# 12                                   Olga Starovoitova
# 13                                      Siobhan Thomas
# 14                        Crapaud Crapaud Sarah Croche
# 15                     Dave Cerri Darren\n202 sleeps!!
# 16                                    Let’s go for it!
# 17                                             Amazing
# 18                           Clarence Prince sick! 😍😍😍
# 19                                                Tina
# 20                                         Waaawwww 😍😍
# 21   The most spectacular island on the planet I wo...
# 22   Hello, im wondering if anyone can help me, me ...
# 23                                   www.beutishop.com
# 24                               C’était magnifique...
# 25                                                Tina
# 26                                  Sandra Fte vamos ?
# 27                                     es precioso....
# 28                             heel mooi ,daar geweest
# 29   Looking forward to seeing the flower carpets i...
# ..                                                 ...
# 170                                   Spettacolare!!!!
# 171
# 172                        Pierre Alexandre Hocquard 😁
# 173                   Na..... volgend jaar maar weer.🤗
# 174                      Ángela Martínez Alejandra HLo
# 175                                           ☀️☀️☀️☀️
# 176             Ne eri innamorato 3000 foto facevi 😂😂😂
# 177                                                 😉😁
# 178       Quel manque de ce sunset 😍 prêt a repartir?😏
# 179                      Mai visto un cielo così bello
# 180                                                🏖🏖🏖
# 181  Voor ons voorlopig ook jaren weer niet op vaka...
# 182                                      Julie Budding
# 183                               Jaren ook gewoon!?😲😲
# 184  Marcel De Nijs nou ja.. onze situatie is nog n...
# 185                                            Deborah
# 186                                       I love you❤️
# 187                                            Jon Cox
# 188                                Mon prochain voyage
# 189   Eso solo Dios y la naturaleza pueden realizarlo🙏
# 190                                       Angie vamos?
# 191                                     Si  pronto xxx
# 192  seguiteci sulla nostra pagina https://www.face...
# 193                                      magari subito
# 194                       https://youtu.be/MnFq23rfe1U
# 195  https://www.facebook.com/experience10for10/\nT...
# 196
# 197          looking forward  to  this  looks  amazing
# 198  Lauren Mc Cool Demi Young am counting down the...
# 199                                       I wana  go x
#
#                  created_time                           post_id hashtags  \
# 0    2018-05-08T09:56:17+0000  145257262182078_1958551770852609       []
# 1    2018-05-08T10:16:08+0000  145257262182078_1958551770852609       []
# 2    2018-05-08T10:19:23+0000  145257262182078_1958551770852609       []
# 3    2018-05-08T10:26:04+0000  145257262182078_1958551770852609       []
# 4    2018-05-08T10:37:28+0000  145257262182078_1958551770852609       []
# 5    2018-05-08T11:04:22+0000  145257262182078_1958551770852609       []
# 6    2018-05-08T11:45:44+0000  145257262182078_1958551770852609       []
# 7    2018-05-08T11:52:20+0000  145257262182078_1958551770852609       []
# 192  2018-03-28T14:19:35+0000  145257262182078_1897945183579935       []
# 193  2018-03-29T18:35:41+0000  145257262182078_1897945183579935       []
# 194  2018-04-13T14:59:39+0000  145257262182078_1897945183579935       []
# 195  2018-04-19T14:18:11+0000  145257262182078_1897945183579935       []
# 196  2018-04-20T17:37:12+0000  145257262182078_1897945183579935       []
# 197  2018-04-22T22:41:04+0000  145257262182078_1897945183579935       []
# 198  2018-04-28T22:24:09+0000  145257262182078_1897945183579935       []
# 199  2018-04-28T23:41:33+0000  145257262182078_1897945183579935       []
#
#                                           preprocessed  \
# 0                                      [nerea, miñano]
# 1                   [alejandra, hlo, ángela, martínez]
# 2    [joanna, wojnowska, i, think, i, need, to, vis...
# 3    [lea, ostrožnik, asija, šerifoski, zana, kunaver]
# 4                                     [lionel, wojcik]
# 5                               [alistair, macfarlane]
# 6                                       [renzo, fedri]
# 7                           [ich, liebe, diese, insel]
# 8                               [aniello, intartaglia]
# 9              [wolfgang, czermak, our, next, project]
# 10   [straordinario, proprio, i, posti, dove, siamo...
# 11                                 [te, amo, tenerife]
# 12                                [olga, starovoitova]
# 13                                   [siobhan, thomas]
# 14                   [crapaud, crapaud, sarah, croche]
# 15                  [dave, cerri, darren, 202, sleeps]
# 16                                 [lets, go, for, it]
# 17                                           [amazing]
# 18                            [clarence, prince, sick]
# 19                                              [tina]
# 20                                          [waaawwww]
# 21   [the, most, spectacular, island, on, the, plan...
# 22   [hello, im, wondering, if, anyone, can, help, ...
# 23                                   [wwwbeutishopcom]
# 24                                [cétait, magnifique]
# 25                                              [tina]
# 26                                [sandra, fte, vamos]
# 27                                      [es, precioso]
# 28                         [heel, mooi, daar, geweest]
# 29   [looking, forward, to, seeing, the, flower, ca...
# ..                                                 ...
# 170                                     [spettacolare]
# 171                                                 []
# 172                      [pierre, alexandre, hocquard]
# 173                    [na, volgend, jaar, maar, weer]
# 174                 [ángela, martínez, alejandra, hlo]
# 175                                                 []
# 176          [ne, eri, innamorato, 3000, foto, facevi]
# 177                                                 []
# 178  [quel, manque, de, ce, sunset, prêt, a, repartir]
# 179               [mai, visto, un, cielo, così, bello]
# 180                                                 []
# 181  [voor, ons, voorlopig, ook, jaren, weer, niet,...
# 182                                   [julie, budding]
# 183                               [jaren, ook, gewoon]
# 184  [marcel, de, nijs, nou, ja, onze, situatie, is...
# 185                                          [deborah]
# 186                                     [i, love, you]
# 187                                         [jon, cox]
# 188                            [mon, prochain, voyage]
# 189  [eso, solo, dios, y, la, naturaleza, pueden, r...
# 190                                     [angie, vamos]
# 191                                  [si, pronto, xxx]
# 192  [seguiteci, sulla, nostra, pagina, httpswwwfac...
# 193                                   [magari, subito]
# 194                          [httpsyoutubemnfq23rfe1u]
# 195  [httpswwwfacebookcomexperience10for10, tenerif...
# 196                                                 []
# 197       [looking, forward, to, this, looks, amazing]
# 198  [lauren, mc, cool, demi, young, am, counting, ...
# 199                                   [i, wana, go, x]
#
#                                                 tagged  \
# 0                          [(nerea, JJ), (miñano, NN)]
# 1    [(alejandra, NN), (hlo, NN), (ángela, NNP), (m...
# 2    [(joanna, NN), (wojnowska, NN), (i, NN), (thin...
# 3    [(lea, NN), (ostrožnik, MD), (asija, VB), (šer...
# 4                        [(lionel, NNS), (wojcik, NN)]
# 5                   [(alistair, NN), (macfarlane, NN)]
# 6                           [(renzo, NN), (fedri, NN)]
# 7    [(ich, JJ), (liebe, VBZ), (diese, JJ), (insel,...
# 8                   [(aniello, NN), (intartaglia, NN)]
# 9    [(wolfgang, NN), (czermak, VBZ), (our, PRP$), ...
# 10   [(straordinario, NN), (proprio, NN), (i, NN), ...
# 11               [(te, NN), (amo, NN), (tenerife, NN)]
# 12                    [(olga, NN), (starovoitova, NN)]
# 13                       [(siobhan, NN), (thomas, NN)]
# 14   [(crapaud, NN), (crapaud, NN), (sarah, NN), (c...
# 15   [(dave, VB), (cerri, NN), (darren, NNS), (202,...
# 16      [(lets, NNS), (go, VBP), (for, IN), (it, PRP)]
# 17                                    [(amazing, VBG)]
# 18          [(clarence, NN), (prince, NN), (sick, NN)]
# 19                                        [(tina, NN)]
# 20                                    [(waaawwww, NN)]
# 21   [(the, DT), (most, RBS), (spectacular, JJ), (i...
# 22   [(hello, NN), (im, NN), (wondering, VBG), (if,...
# 23                             [(wwwbeutishopcom, NN)]
# 24                    [(cétait, NN), (magnifique, NN)]
# 25                                        [(tina, NN)]
# 26              [(sandra, NN), (fte, NN), (vamos, NN)]
# 27                          [(es, NN), (precioso, NN)]
# 28   [(heel, NN), (mooi, NNS), (daar, VBP), (gewees...
# 29   [(looking, VBG), (forward, RB), (to, TO), (see...
# ..                                                 ...
# 170                               [(spettacolare, NN)]
# 171                                                 []
# 172   [(pierre, JJ), (alexandre, NNS), (hocquard, NN)]
# 173  [(na, JJ), (volgend, NN), (jaar, NN), (maar, N...
# 174  [(ángela, JJ), (martínez, NN), (alejandra, NN)...
# 175                                                 []
# 176  [(ne, JJ), (eri, NN), (innamorato, NN), (3000,...
# 177                                                 []
# 178  [(quel, NN), (manque, NN), (de, IN), (ce, FW),...
# 179  [(mai, NN), (visto, NN), (un, JJ), (cielo, NN)...
# 180                                                 []
# 181  [(voor, JJ), (ons, NNS), (voorlopig, VBP), (oo...
# 182                       [(julie, NN), (budding, NN)]
# 183           [(jaren, NNS), (ook, VBP), (gewoon, NN)]
# 184  [(marcel, NN), (de, IN), (nijs, FW), (nou, JJ)...
# 185                                    [(deborah, NN)]
# 186                 [(i, NN), (love, VBP), (you, PRP)]
# 187                             [(jon, NN), (cox, NN)]
# 188          [(mon, NN), (prochain, NN), (voyage, NN)]
# 189  [(eso, NN), (solo, NN), (dios, NNS), (y, VBP),...
# 190                         [(angie, NN), (vamos, NN)]
# 191                [(si, NN), (pronto, NN), (xxx, NN)]
# 192  [(seguiteci, NN), (sulla, NN), (nostra, JJ), (...
# 193                       [(magari, NN), (subito, NN)]
# 194                    [(httpsyoutubemnfq23rfe1u, NN)]
# 195  [(httpswwwfacebookcomexperience10for10, NN), (...
# 196                                                 []
# 197  [(looking, VBG), (forward, RB), (to, TO), (thi...
# 198  [(lauren, NNS), (mc, VBP), (cool, JJ), (demi, ...
# 199         [(i, NN), (wana, VBP), (go, VBP), (x, JJ)]
#
#                                               keywords  \
# 0                                      [nerea, miñano]
# 1                   [alejandra, hlo, ángela, martínez]
# 2    [joanna, wojnowska, i, think, i, need, visit, ...
# 3               [lea, asija, šerifoski, zana, kunaver]
# 4                                     [lionel, wojcik]
# 5                               [alistair, macfarlane]
# 6                                       [renzo, fedri]
# 7                           [ich, liebe, diese, insel]
# 8                               [aniello, intartaglia]
# 9                   [wolfgang, czermak, next, project]
# 10   [straordinario, proprio, i, posti, dove, siamo...
# 11                                 [te, amo, tenerife]
# 12                                [olga, starovoitova]
# 13                                   [siobhan, thomas]
# 14                   [crapaud, crapaud, sarah, croche]
# 15                       [dave, cerri, darren, sleeps]
# 16                                          [lets, go]
# 17                                           [amazing]
# 18                            [clarence, prince, sick]
# 19                                              [tina]
# 20                                          [waaawwww]
# 21   [spectacular, island, planet, i, wonder, many,...
# 22   [hello, im, wondering, anyone, help, boyfriend...
# 23                                   [wwwbeutishopcom]
# 24                                [cétait, magnifique]
# 25                                              [tina]
# 26                                [sandra, fte, vamos]
# 27                                      [es, precioso]
# 28                         [heel, mooi, daar, geweest]
# 29            [looking, seeing, flower, carpets, june]
# ..                                                 ...
# 170                                     [spettacolare]
# 171                                                 []
# 172                      [pierre, alexandre, hocquard]
# 173                    [na, volgend, jaar, maar, weer]
# 174                 [ángela, martínez, alejandra, hlo]
# 175                                                 []
# 176                [ne, eri, innamorato, foto, facevi]
# 177                                                 []
# 178             [quel, manque, sunset, prêt, repartir]
# 179               [mai, visto, un, cielo, così, bello]
# 180                                                 []
# 181  [voor, ons, voorlopig, ook, jaren, weer, niet,...
# 182                                   [julie, budding]
# 183                               [jaren, ook, gewoon]
# 184  [marcel, nou, ja, onze, situatie, is, nog, nie...
# 185                                          [deborah]
# 186                                          [i, love]
# 187                                         [jon, cox]
# 188                            [mon, prochain, voyage]
# 189  [eso, solo, dios, y, la, naturaleza, pueden, r...
# 190                                     [angie, vamos]
# 191                                  [si, pronto, xxx]
# 192  [seguiteci, sulla, nostra, pagina, httpswwwfac...
# 193                                   [magari, subito]
# 194                          [httpsyoutubemnfq23rfe1u]
# 195  [httpswwwfacebookcomexperience10for10, tenerif...
# 196                                                 []
# 197                          [looking, looks, amazing]
# 198  [lauren, mc, cool, demi, young, am, counting, ...
# 199                                   [i, wana, go, x]
#
#                                           noun_phrases                date
# 0                                       [nerea miñano] 2018-05-08 09:56:17
# 1                                                   [] 2018-05-08 10:16:08
# 2                                                   [] 2018-05-08 10:19:23
# 3                                                   [] 2018-05-08 10:26:04
# 4                                                   [] 2018-05-08 10:37:28
# 5                                                   [] 2018-05-08 11:04:22
# 6                                                   [] 2018-05-08 11:45:44
# 7                                        [diese insel] 2018-05-08 11:52:20
# 8                                                   [] 2018-05-08 12:26:34
# 9                                       [next project] 2018-05-08 12:40:50
# 10                                                  [] 2018-05-08 13:21:53
# 11                                                  [] 2018-05-08 13:25:47
# 12                                                  [] 2018-05-08 14:42:39
# 13                                                  [] 2018-05-08 16:35:59
# 14                                                  [] 2018-05-08 17:37:06
# 6                                      [renzo, fedri]
# 7                          [ich, liebe, diese, insel]
# 8                              [aniello, intartaglia]
# 9             [wolfgang, czermak, our, next, project]
# 10  [straordinario, proprio, i, posti, dove, siamo...
# 11                                [te, amo, tenerife]
# 12                               [olga, starovoitova]
# 13                                  [siobhan, thomas]
# 14                  [crapaud, crapaud, sarah, croche]
# 15                 [dave, cerri, darren, 202, sleeps]
# 16                                [lets, go, for, it]
# 17                                          [amazing]
# 18                           [clarence, prince, sick]
# 19                                             [tina]
# 20                                         [waaawwww]
# 21  [the, most, spectacular, island, on, the, plan...
# 22  [hello, im, wondering, if, anyone, can, help, ...
# 23                                  [wwwbeutishopcom]
# 24                               [cétait, magnifique]
# 25                                             [tina]
# 26                               [sandra, fte, vamos]
# 27                                     [es, precioso]
# 28                        [heel, mooi, daar, geweest]
# 29  [looking, forward, to, seeing, the, flower, ca...
# ..                                                ...
# 70          [où, sont, ces, beaux, jardins, victoria]
# 71                                      [viv, stubbs]
# 72                  [aww, pretty, where, is, that, x]
# 73                         [karine, baron, le, corff]
# 74                                          [bientôt]
# 75                                      [tanya, olla]
# 76                                [diana, soldevilla]
# 77  [muy, chulo, yo, eatube, ahí, mismoby, es, pre...
# 78                              [joël, morandinfanti]
# 79             [jaimerai, tant, partir, en, décembre]
# 80   [cela, sent, lenvie, de, partir, denis, infanti]
# 81                    [faut, quon, aille, là, bas, d]
# 82                                    [ben, benjamin]
# 83                                     [que, paraiso]
# 84                                 [stefano, porfido]
# 85                            [gaetano, de, lorenzis]
# 86  [oui, mais, faudra, traverser, la, montagne, p...
# 87                                          [merlijn]
# 88  [nous, y, étions, il, y, à, 15, jours, c, est,...
# 89                                  [echo, de, menos]
# 90            [es, hermoso, gracias, algún, día, iré]
# 91                   [je, confirme, cest, magnifique]
# 92                                      [tes, sur, o]
# 93                                             [ouii]
# 94        [cory, harris, check, out, their, fb, page]
# 95                                  [wwwbeutishopcom]
# 96  [mi, certamen, se, realizará, en, la, orotava,...
# 97  [rebekka, fjellheim, ragna, fjellheim, mathias...
# 98                                      [hala, daoud]
# 99                                 [laura, alex, prs]
#
#                                                tagged  \
# 0                         [(nerea, JJ), (miñano, NN)]
# 1   [(alejandra, NN), (hlo, NN), (ángela, NNP), (m...
# 2   [(joanna, NN), (wojnowska, NN), (i, NN), (thin...
# 3   [(lea, NN), (ostrožnik, MD), (asija, VB), (šer...
# 4                       [(lionel, NNS), (wojcik, NN)]
# 5                  [(alistair, NN), (macfarlane, NN)]
# 6                          [(renzo, NN), (fedri, NN)]
# 7   [(ich, JJ), (liebe, VBZ), (diese, JJ), (insel,...
# 8                  [(aniello, NN), (intartaglia, NN)]
# 9   [(wolfgang, NN), (czermak, VBZ), (our, PRP$), ...
# 10  [(straordinario, NN), (proprio, NN), (i, NN), ...
# 11              [(te, NN), (amo, NN), (tenerife, NN)]
# 12                   [(olga, NN), (starovoitova, NN)]
# 13                      [(siobhan, NN), (thomas, NN)]
# 14  [(crapaud, NN), (crapaud, NN), (sarah, NN), (c...
# 15  [(dave, VB), (cerri, NN), (darren, NNS), (202,...
# 16     [(lets, NNS), (go, VBP), (for, IN), (it, PRP)]
# 17                                   [(amazing, VBG)]
# 18         [(clarence, NN), (prince, NN), (sick, NN)]
# 19                                       [(tina, NN)]
# 20                                   [(waaawwww, NN)]
# 21  [(the, DT), (most, RBS), (spectacular, JJ), (i...
# 22  [(hello, NN), (im, NN), (wondering, VBG), (if,...
# 23                            [(wwwbeutishopcom, NN)]
# 24                   [(cétait, NN), (magnifique, NN)]
# 25                                       [(tina, NN)]
# 26             [(sandra, NN), (fte, NN), (vamos, NN)]
# 27                         [(es, NN), (precioso, NN)]
# 28  [(heel, NN), (mooi, NNS), (daar, VBP), (gewees...
# 29  [(looking, VBG), (forward, RB), (to, TO), (see...
# ..                                                ...
# 70  [(où, JJ), (sont, NN), (ces, NNS), (beaux, VBP...
# 71                          [(viv, NN), (stubbs, NN)]
# 72  [(aww, NN), (pretty, NN), (where, WRB), (is, V...
# 73  [(karine, VB), (baron, NN), (le, NN), (corff, ...
# 74                                    [(bientôt, NN)]
# 75                          [(tanya, NN), (olla, NN)]
# 76                   [(diana, NNS), (soldevilla, NN)]
# 77  [(muy, NN), (chulo, NN), (yo, NN), (eatube, NN...
# 78                  [(joël, NN), (morandinfanti, NN)]
# 79  [(jaimerai, NN), (tant, JJ), (partir, NN), (en...
# 80  [(cela, NN), (sent, VBD), (lenvie, NN), (de, I...
# 81  [(faut, JJ), (quon, NN), (aille, NN), (là, NN)...
# 82                        [(ben, NN), (benjamin, NN)]
# 83                         [(que, NN), (paraiso, NN)]
# 84                     [(stefano, NN), (porfido, NN)]
# 85          [(gaetano, NN), (de, IN), (lorenzis, FW)]
# 86  [(oui, JJ), (mais, NN), (faudra, NN), (travers...
# 87                                    [(merlijn, NN)]
# 88  [(nous, JJ), (y, NN), (étions, NNS), (il, VBP)...
# 89                [(echo, NN), (de, IN), (menos, FW)]
# 90  [(es, NN), (hermoso, NN), (gracias, NN), (algú...
# 91  [(je, NN), (confirme, NN), (cest, NN), (magnif...
# 92                  [(tes, NNS), (sur, VBP), (o, NN)]
# 93                                       [(ouii, NN)]
# 94  [(cory, NN), (harris, NN), (check, VB), (out, ...
# 95                            [(wwwbeutishopcom, NN)]
# 96  [(mi, NNS), (certamen, NNS), (se, VBP), (reali...
# 97  [(rebekka, NN), (fjellheim, NN), (ragna, NN), ...
# 98                          [(hala, NN), (daoud, NN)]
# 99               [(laura, NN), (alex, JJ), (prs, NN)]
#
#                                              keywords  \
# 0                                     [nerea, miñano]
# 1                  [alejandra, hlo, ángela, martínez]
# 2   [joanna, wojnowska, i, think, i, need, visit, ...
# 3              [lea, asija, šerifoski, zana, kunaver]
# 4                                    [lionel, wojcik]
# 5                              [alistair, macfarlane]
# 6                                      [renzo, fedri]
# 7                          [ich, liebe, diese, insel]
# 8                              [aniello, intartaglia]
# 9                  [wolfgang, czermak, next, project]
# 10  [straordinario, proprio, i, posti, dove, siamo...
# 11                                [te, amo, tenerife]
# 12                               [olga, starovoitova]
# 13                                  [siobhan, thomas]
# 14                  [crapaud, crapaud, sarah, croche]
# 29                                                 [] 2018-05-03 10:50:52
# ..                                                ...                 ...
# 70                                          [où sont] 2018-05-03 19:52:44
# 71                                                 [] 2018-05-03 19:58:15
# 72                                                 [] 2018-05-03 20:01:24
# 73                                                 [] 2018-05-03 20:34:46
# 74                                                 [] 2018-05-03 21:04:53
# 75                                                 [] 2018-05-03 21:53:36
# 76                                                 [] 2018-05-03 23:35:20
# 77                                                 [] 2018-05-04 05:31:47
# 78                                                 [] 2018-05-04 06:55:42
# 79                                      [tant partir] 2018-05-04 06:59:13
# 80                                                 [] 2018-05-04 08:17:05
# 81                                        [faut quon] 2018-05-04 09:05:52
# 82                                                 [] 2018-05-04 09:13:50
# 83                                                 [] 2018-05-04 10:12:56
# 84                                                 [] 2018-05-04 10:28:28
# 85                                                 [] 2018-05-04 11:37:57
# 86                                         [oui mais] 2018-05-04 14:18:16
# 87                                                 [] 2018-05-04 18:11:46
# 88                                     [nous y, n es] 2018-05-04 20:00:21
# 89                                                 [] 2018-05-05 00:03:12
# 90                                                 [] 2018-05-05 05:01:09
# 91                                                 [] 2018-05-05 06:16:38
# 92                                                 [] 2018-05-07 07:05:34
# 93                                                 [] 2018-05-07 12:54:50
# 94                                          [fb page] 2018-05-09 21:20:18
# 95                                                 [] 2018-05-15 16:30:53
# 96                       [podrian darle, a mi página] 2018-05-16 14:43:23
# 97                                                 [] 2018-03-31 08:23:42
# 98                                                 [] 2018-03-31 08:27:39
# 99                                         [alex prs] 2018-03-31 08:29:38
#
#                                               alchemy
# 0                                                None
# 1                                                None
# 2   (en, {'sadness': 0.014019, 'joy': 0.606376, 'f...
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9   (en, {'sadness': 0.028121, 'joy': 0.553532, 'f...
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16  (en, {'sadness': 0.295808, 'joy': 0.313385, 'f...
# 17                                               None
# 18  (en, {'sadness': 0.03833, 'joy': 0.841184, 'fe...
# 19                                               None
# 20                                               None
# 21  (en, {'sadness': 0.03974, 'joy': 0.859113, 'fe...
# 22  (en, {'sadness': 0.176933, 'joy': 0.462465, 'f...
# 23  (en, {'sadness': 0.0, 'joy': 0.0, 'fear': 0.0,...
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29  (en, {'sadness': 0.112262, 'joy': 0.693648, 'f...
# ..                                                ...
# 70                                               None
# 71                                               None
# 72  (en, {'sadness': 0.112923, 'joy': 0.515975, 'f...
# 73                                               None
# 74                                               None
# 75                                               None
# 76                                               None
# 77                                               None
# 78                                               None
# 79                                               None
# 80                                               None
# 81                                               None
# 82                                               None
# 83                                               None
# 84                                               None
# 85                                               None
# 86                                               None
# 87                                               None
# 88                                               None
# 89                                               None
# 90                                               None
# 91                                               None
# 92                                               None
# 93                                               None
# 94  (en, {'sadness': 0.184764, 'joy': 0.491238, 'f...
# 95  (en, {'sadness': 0.0, 'joy': 0.0, 'fear': 0.0,...
# 96                                               None
# 97                                               None
# 98                                               None
# 99                                               None
# [100 rows x 10 columns]

# %%
print(alchemy['alchemy'])
# Out:
# 0                                                  None
# 1     (es, None, {'score': 0.501288, 'label': 'posit...
# 2     (en, {'sadness': 0.014019, 'joy': 0.606376, 'f...
# 3                                                  None
# 4                                                  None
# 5                                                  None
# 6                                                  None
# 7     (de, None, {'score': 0.903016, 'label': 'posit...
# 8        (it, None, {'score': 0.0, 'label': 'neutral'})
# 9     (en, {'sadness': 0.028121, 'joy': 0.553532, 'f...
# 10    (it, None, {'score': 0.788407, 'label': 'posit...
# 11                                                 None
# 12                                                 None
# 13                                                 None
# 14                                                 None
# 15                                                 None
# 16    (en, {'sadness': 0.295808, 'joy': 0.313385, 'f...
# 17                                                 None
# 18    (en, {'sadness': 0.03833, 'joy': 0.841184, 'fe...
# 19                                                 None
# 20                                                 None
# 21    (en, {'sadness': 0.03974, 'joy': 0.859113, 'fe...
# 22    (en, {'sadness': 0.176933, 'joy': 0.462465, 'f...
# 23    (en, {'sadness': 0.0, 'joy': 0.0, 'fear': 0.0,...
# 24    (fr, None, {'score': 0.903959, 'label': 'posit...
# 25                                                 None
# 26    (pt, None, {'score': 0.459304, 'label': 'posit...
# 27    (es, None, {'score': 0.62003, 'label': 'positi...
# 28                                                 None
# 29    (en, {'sadness': 0.112262, 'joy': 0.693648, 'f...
#                             ...
# 70       (fr, None, {'score': 0.0, 'label': 'neutral'})
# 71                                                 None
# 72    (en, {'sadness': 0.112923, 'joy': 0.515975, 'f...
# 73                                                 None
# 74    (fr, None, {'score': 0.908251, 'label': 'posit...
# 75                                                 None
# 76       (it, None, {'score': 0.0, 'label': 'neutral'})
# 77    (es, None, {'score': 0.915238, 'label': 'posit...
# 78       (fr, None, {'score': 0.0, 'label': 'neutral'})
# 79    (fr, None, {'score': -0.45238, 'label': 'negat...
# 80       (pt, None, {'score': 0.0, 'label': 'neutral'})
# 81       (fr, None, {'score': 0.0, 'label': 'neutral'})
# 82                                                 None
# 83                                                 None
# 84       (it, None, {'score': 0.0, 'label': 'neutral'})
# 85       (es, None, {'score': 0.0, 'label': 'neutral'})
# 86       (fr, None, {'score': 0.0, 'label': 'neutral'})
# 87                                                 None
# 88    (fr, None, {'score': 0.441821, 'label': 'posit...
# 89    (es, None, {'score': -0.876888, 'label': 'nega...
# 90    (es, None, {'score': 0.75337, 'label': 'positi...
# 91    (fr, None, {'score': 0.877958, 'label': 'posit...
# 92                                                 None
# 93                                                 None
# 94    (en, {'sadness': 0.184764, 'joy': 0.491238, 'f...
# 95    (en, {'sadness': 0.0, 'joy': 0.0, 'fear': 0.0,...
# 96    (es, None, {'score': 0.566601, 'label': 'posit...
# 97                                                 None
# 98                                                 None
# 99                                                 None
# Name: alchemy, Length: 100, dtype: object

# %%
emotions = []
sentiments = []
languages = []

for p in alchemy['alchemy']:
    if not p == None:
        languages.append(p[0])
        if not p[1] == None:
            emotions.append(p[1])
        sentiments.append(p[2])

# %%
print(sentiments)
# Out:
# [{'score': 0.501288, 'label': 'positive'}, {'score': 0.719416, 'label': 'positive'}, {'score': 0.903016, 'label': 'positive'}, {'score': 0.0, 'label': 'neutral'}, {'score': 0.0, 'label': 'neutral'}, {'score': 0.788407, 'label': 'positive'}, {'score': 0.441563, 'label': 'positive'}, {'score': -0.385483, 'label': 'negative'}, {'score': 0.617007, 'label': 'positive'}, {'score': 0.932438, 'label': 'positive'}, {'score': 0.0, 'label': 'neutral'}, {'score': 0.903959, 'label': 'positive'}, {'score': 0.459304, 'label': 'positive'}, {'score': 0.62003, 'label': 'positive'}, {'score': 0.846557, 'label': 'positive'}, {'score': 0.914759, 'label': 'positive'}, {'score': 0.688328, 'label': 'positive'}, {'score': 0.640365, 'label': 'positive'}, {'score': 0.0, 'label': 'neutral'}, {'score': 0.0, 'label': 'neutral'}, {'score': -0.422225, 'label': 'negative'}, {'score': 0.401119, 'label': 'positive'}, {'score': -0.491958, 'label': 'negative'}, {'score': 0.358572, 'label': 'positive'}, {'score': 0.0, 'label': 'neutral'}, {'score': 0.0, 'label': 'neutral'}, {'score': 0.506751, 'label': 'positive'}, {'score': 0.785076, 'label': 'positive'}, {'score': 0.552272, 'label': 'positive'}, {'score': 0.763493, 'label': 'positive'}, {'score': 0.0, 'label': 'neutral'}, {'score': -0.0329848, 'label': 'negative'}, {'score': 0.744642, 'label': 'positive'}, {'score': 0.879518, 'label': 'positive'}, {'score': 0.254069, 'label': 'positive'}, {'score': -0.731279, 'label': 'negative'}, {'score': 0.0, 'label': 'neutral'}, {'score': 0.0, 'label': 'neutral'}, {'score': 0.76987, 'label': 'positive'}, {'score': 0.0, 'label': 'neutral'}, {'score': 0.0, 'label': 'neutral'}, {'score': 0.908251, 'label': 'positive'}, {'score': 0.0, 'label': 'neutral'}, {'score': 0.915238, 'label': 'positive'}, {'score': 0.0, 'label': 'neutral'}, {'score': -0.45238, 'label': 'negative'}, {'score': 0.0, 'label': 'neutral'}, {'score': 0.0, 'label': 'neutral'}, {'score': 0.0, 'label': 'neutral'}, {'score': 0.0, 'label': 'neutral'}, {'score': 0.0, 'label': 'neutral'}, {'score': 0.441821, 'label': 'positive'}, {'score': -0.876888, 'label': 'negative'}, {'score': 0.75337, 'label': 'positive'}, {'score': 0.877958, 'label': 'positive'}, {'score': 0.643577, 'label': 'positive'}, {'score': 0.0, 'label': 'neutral'}, {'score': 0.566601, 'label': 'positive'}]

# %%
df_emotions = pandas.DataFrame(emotions)
df_sentiments = pandas.DataFrame(sentiments)
df_languages = pandas.DataFrame(languages)

# %%
print(df_sentiments)
# Out:
#       label     score
# 0  positive  0.719415

# %%
df_emotions = df_emotions.apply(pandas.to_numeric, errors='ignore')
print(df_emotions)
# Out:
#        anger   disgust      fear       joy   sadness
# 0   0.050330  0.222445  0.177395  0.606376  0.014019
# 1   0.080281  0.067374  0.172176  0.553532  0.028121
# 2   0.082661  0.082703  0.089767  0.313385  0.295808
# 3   0.002992  0.046284  0.040787  0.841184  0.038330
# 4   0.004910  0.035783  0.053902  0.859113  0.039740
# 5   0.211798  0.079207  0.090110  0.462465  0.176933
# 6   0.000000  0.000000  0.000000  0.000000  0.000000
# 7   0.012971  0.017566  0.034517  0.693648  0.112262
# 8   0.125501  0.346354  0.031809  0.232072  0.168792
# 9   0.093238  0.119665  0.070971  0.171966  0.178578
# 10  0.005214  0.003523  0.003589  0.908682  0.067607
# 11  0.011706  0.005305  0.014687  0.520163  0.030540
# 12  0.081880  0.032697  0.021205  0.033314  0.037891
# 13  0.009423  0.055033  0.036842  0.853761  0.042573
# 14  0.064520  0.025552  0.383875  0.515975  0.112923
# 15  0.094399  0.116529  0.107638  0.491238  0.184764
# 16  0.000000  0.000000  0.000000  0.000000  0.000000
# 17  0.004103  0.029865  0.041249  0.809153  0.042937
# 18  0.090723  0.077654  0.087573  0.185315  0.144548
# 19  0.024595  0.077722  0.043611  0.786892  0.056339
# 20  0.084759  0.184482  0.137501  0.364719  0.372609
# 21  0.000000  0.000000  0.000000  0.000000  0.000000
# 22  0.001239  0.012736  0.017429  0.910930  0.030404
# 23  0.001265  0.013696  0.017565  0.938602  0.012411
# 24  0.093178  0.120860  0.070749  0.169642  0.179683
# 25  0.012046  0.039570  0.039664  0.694776  0.037262
# 26  0.044371  0.020842  0.408939  0.389979  0.178211
# 27  0.081981  0.087751  0.060999  0.354538  0.147340
# 28  0.002282  0.007302  0.012753  0.948948  0.016852
# 29  0.000000  0.000000  0.000000  0.000000  0.000000
# 30  0.025714  0.005833  0.009821  0.917388  0.028276
# 31  0.006026  0.004419  0.012567  0.914336  0.044310
# 32  0.005857  0.007677  0.011328  0.958320  0.010808

# %%
df_emotions_means = df_emotions.transpose().apply(numpy.mean, axis=1)

# %%
df_emotions_means.plot(kind='bar', legend=False)

# %%
print(df_sentiments)
df_sentiments = df_sentiments['score'].apply(pandas.to_numeric, errors='ignore')
df_sentiments_means = df_sentiments.transpose().apply(numpy.mean, axis=1)
#df_sentiments_means.plot(kind='bar', legend=False)
# Out:
#        label     score
# 0   positive  0.501288
# 1   positive  0.719416
# 2   positive  0.903016
# 3    neutral  0.000000
# 4    neutral  0.000000
# 5   positive  0.788407
# 6   positive  0.441563
# 7   negative -0.385483
# 8   positive  0.617007
# 9   positive  0.932438
# 10   neutral  0.000000
# 11  positive  0.903959
# 12  positive  0.459304
# 13  positive  0.620030
# 14  positive  0.846557
# 15  positive  0.914759
# 16  positive  0.688328
# 17  positive  0.640365
# 18   neutral  0.000000
# 19   neutral  0.000000
# 20  negative -0.422225
# 21  positive  0.401119
# 22  negative -0.491958
# 23  positive  0.358572
# 24   neutral  0.000000
# 25   neutral  0.000000
# 26  positive  0.506751
# 27  positive  0.785076
# 28  positive  0.552272
# 29  positive  0.763493
# 30   neutral  0.000000
# 31  negative -0.032985
# 32  positive  0.744642
# 33  positive  0.879518
# 34  positive  0.254069
# 35  negative -0.731279
# 36   neutral  0.000000
# 37   neutral  0.000000
# 38  positive  0.769870
# 39   neutral  0.000000
# 40   neutral  0.000000
# 41  positive  0.908251
# 42   neutral  0.000000
# 43  positive  0.915238
# 44   neutral  0.000000
# 45  negative -0.452380
# 46   neutral  0.000000
# 47   neutral  0.000000
# 48   neutral  0.000000
# 49   neutral  0.000000
# 50   neutral  0.000000
# 51  positive  0.441821
# 52  negative -0.876888
# 53  positive  0.753370
# 54  positive  0.877958
# 55  positive  0.643577
# 56   neutral  0.000000
# 57  positive  0.566601
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-66-29b675675a75> in <module>()
#       1 print(df_sentiments)
#       2 #df_sentiments = df_sentiments['score'].apply(pandas.to_numeric, errors='ignore')
# ----> 3 df_sentiments_means = df_sentiments['score'].transpose().apply(numpy.mean, axis=1)
#       4 #df_sentiments_means.plot(kind='bar', legend=False)
#
# d:\python\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    2549             else:
#    2550                 values = self.asobject
# -> 2551                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2552
#    2553         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src\inference.pyx in pandas._libs.lib.map_infer()
#
# d:\python\lib\site-packages\pandas\core\series.py in <lambda>(x)
#    2536         # handle ufuncs and lambdas
#    2537         if kwds or args and not isinstance(func, np.ufunc):
# -> 2538             f = lambda x: func(x, *args, **kwds)
#    2539         else:
#    2540             f = func
#
# d:\python\lib\site-packages\numpy\core\fromnumeric.py in mean(a, axis, dtype, out, keepdims)
#    2955
#    2956     return _methods._mean(a, axis=axis, dtype=dtype,
# -> 2957                           out=out, **kwargs)
#    2958
#    2959
#
# d:\python\lib\site-packages\numpy\core\_methods.py in _mean(a, axis, dtype, out, keepdims)
#      55
#      56     is_float16_result = False
# ---> 57     rcount = _count_reduce_items(arr, axis)
#      58     # Make this warning show up first
#      59     if rcount == 0:
#
# d:\python\lib\site-packages\numpy\core\_methods.py in _count_reduce_items(arr, axis)
#      48     items = 1
#      49     for ax in axis:
# ---> 50         items *= arr.shape[ax]
#      51     return items
#      52
#
# IndexError: tuple index out of range

# %%
lst_tokens = list(itertools.chain.from_iterable(df_languages[0]))
print(df_languages)
print(df_languages[0].value_counts())
plot = df_languages[0].value_counts().plot(kind='bar', title='Language')
# Out:
#       0
# 0    es
# 1    en
# 2    de
# 3    it
# 4    en
# 5    it
# 6    en
# 7    en
# 8    en
# 9    en
# 10   en
# 11   fr
# 12   pt
# 13   es
# 14   en
# 15   es
# 16   fr
# 17   fr
# 18   it
# 19   fr
# 20   fr
# 21   fr
# 22   fr
# 23   fr
# 24   fr
# 25   de
# 26   en
# 27   es
# 28   es
# 29   en
# ..   ..
# 71   en
# 72   en
# 73   es
# 74   es
# 75   es
# 76   it
# 77   it
# 78   en
# 79   en
# 80   fr
# 81   pt
# 82   en
# 83   it
# 84   fr
# 85   it
# 86   it
# 87   it
# 88   es
# 89   it
# 90   fr
# 91   it
# 92   en
# 93   en
# 94   fr
# 95   es
# 96   it
# 97   en
# 98   en
# 99   en
# 100  en
#
# [101 rows x 1 columns]
# en    33
# fr    25
# es    20
# it    18
# pt     3
# de     2
# Name: 0, dtype: int64
