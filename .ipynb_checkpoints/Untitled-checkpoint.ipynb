# %%
#! /usr/bin/env python
# -*- coding: utf-8 -*-

import requests
import json
import pymongo
import pandas
import re
import nltk
import numpy
import itertools
import datetime 
import ggplot
import tabpy_client


from ggplot import *
from matplotlib import pyplot as plt
from wordcloud import WordCloud
from pymongo import MongoClient
from requests_oauthlib import OAuth2
from tqdm import tqdm

from watson_developer_cloud import NaturalLanguageUnderstandingV1
from watson_developer_cloud.natural_language_understanding_v1 \
  import Features, EmotionOptions, SentimentOptions

#Base de datos 
client = MongoClient('localhost:27017')
db = client.db_analyzer
db_analyzer = db.analyzer
collection_posts = db_analyzer.posts
collection_comments = db_analyzer.comments
# Out:
# d:\python\lib\site-packages\ggplot\utils.py:81: FutureWarning: pandas.tslib is deprecated and will be removed in a future version.
# You can access Timestamp as pandas.Timestamp
#   pd.tslib.Timestamp,
# d:\python\lib\site-packages\ggplot\stats\smoothers.py:4: FutureWarning: The pandas.lib module is deprecated and will be removed in a future version. These are private functions and can be accessed from pandas._libs.lib instead
#   from pandas.lib import Timestamp
# d:\python\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
#Limpiamos la base de datos para que no se repliquen los datos o interfieran con los de otras páginas
collection_posts.delete_many({})
collection_comments.delete_many({})

# %%
id = "turismoTenerife"              # id de la página que va a ser analizada
"""Páginas usadas
 * tenerifevacanze
 * VisitTenerifeES
 * siampark
 * turismoTenerife"""



url = 'https://graph.facebook.com/v2.12/'
page_url = 'https://graph.facebook.com/v2.12/%s/feed?fields=id,message,reactions,shares,from,caption,created_time,likes.summary(true)' %id
print(page_url)
# Todos los campos deben de ser especificados
comments_url = 'https://graph.facebook.com/v2.12/{post_id}/comments?filter=stream&limit=100'

# Variable con el token de acceso de Facebook
params = {'access_token' : 'EAANBb7LjFH8BAM8Gn8bwOkcPZAqhu14iNxsz7M0FE5MAzUYtU6ZBBuW8Fz8iSRaEV9yslYEqZCN6Du3aBKXGz4eCuSGzJ1uroi99lvzStJI9SeL8XZCo8QrQaLUD1ZANZBXdit4QBtcd5QojH21JIV1loqyxrGd1qYdTU6Ekv5UQZDZD'}
posts = requests.get(page_url, params = params)
posts = posts.json()
print(posts)
# Out:
# https://graph.facebook.com/v2.12/turismoTenerife/feed?fields=id,message,reactions,shares,from,caption,created_time,likes.summary(true)
# {'data': [{'id': '215473732566847_215942402519980', 'message': 'Recorre la cueva del viento, el tubo volcánico más grande de Europa, y admira el Drago Milenario en Icod de los Vinos\n\n#Drago #Tenerife #TuboVolcánico #Icod #Paraiso', 'shares': {'count': 15}, 'from': {'name': 'Turismo Tenerife', 'id': '215473732566847'}, 'created_time': '2018-06-12T11:25:54+0000', 'likes': {'data': [], 'paging': {'cursors': {'before': 'MTAyMTYxMDkxNzQ3OTI5OTYZD', 'after': 'MTAzNTI5NTg4MzI4NDc1NwZDZD'}, 'next': 'https://graph.facebook.com/v3.0/215473732566847_215942402519980/likes?access_token=EAANBb7LjFH8BAM8Gn8bwOkcPZAqhu14iNxsz7M0FE5MAzUYtU6ZBBuW8Fz8iSRaEV9yslYEqZCN6Du3aBKXGz4eCuSGzJ1uroi99lvzStJI9SeL8XZCo8QrQaLUD1ZANZBXdit4QBtcd5QojH21JIV1loqyxrGd1qYdTU6Ekv5UQZDZD&summary=true&limit=25&after=MTAzNTI5NTg4MzI4NDc1NwZDZD'}, 'summary': {'total_count': 28, 'can_like': True, 'has_liked': False}}}, {'id': '215473732566847_215939769186910', 'message': 'Piérdete en los montes de Anaga  y disfruta de la Laurisilva\n\n#Anaga #Tenerife #SC #Laurisilva #Bosque', 'shares': {'count': 6}, 'from': {'name': 'Turismo Tenerife', 'id': '215473732566847'}, 'created_time': '2018-06-12T11:17:37+0000', 'likes': {'data': [], 'paging': {'cursors': {'before': 'MTAyMTYxMDkxNzQ3OTI5OTYZD', 'after': 'MTAzNTI5NTg4MzI4NDc1NwZDZD'}}, 'summary': {'total_count': 24, 'can_like': True, 'has_liked': False}}}, {'id': '215473732566847_215935885853965', 'message': 'Disfruta de las playas paradisíacas de Los Cristianos\n\n#Tenerife #Playas #VenAlParaiso #LosCristianos #LasVistas', 'shares': {'count': 4}, 'from': {'name': 'Turismo Tenerife', 'id': '215473732566847'}, 'created_time': '2018-06-12T11:06:06+0000', 'likes': {'data': [], 'paging': {'cursors': {'before': 'MTAyMTYxMDkxNzQ3OTI5OTYZD', 'after': 'MTIyNTQ5OTY5NDI1MjI0MwZDZD'}}, 'summary': {'total_count': 23, 'can_like': True, 'has_liked': False}}}, {'id': '215473732566847_215933575854196', 'message': 'Observa el vasto campo de lava que se extiende desde Montaña Grande hasta el mar en Güimar. Disfruta del paisaje de antaño en Canarias.\n\n#Malpais #MontañaGrande #Güimar #Tenerife #Volcán #Pirámides', 'shares': {'count': 3}, 'from': {'name': 'Turismo Tenerife', 'id': '215473732566847'}, 'created_time': '2018-06-12T10:59:00+0000', 'likes': {'data': [], 'paging': {'cursors': {'before': 'MTAyMTYxMDkxNzQ3OTI5OTYZD', 'after': 'MjE1NDczNzMyNTY2ODQ3'}}, 'summary': {'total_count': 22, 'can_like': True, 'has_liked': False}}}, {'id': '215473732566847_215906422523578', 'message': 'Lánzate al mar y navega por sus costas para obtener una nueva experiencia.\n\nRelájate y disfruta del espectacular Acantilado de Los Gigantes en compañía de los delfines.\n#Tenerife #Paraiso #Gigantes #Delfines #Relax', 'shares': {'count': 7}, 'from': {'name': 'Turismo Tenerife', 'id': '215473732566847'}, 'created_time': '2018-06-12T09:54:46+0000', 'likes': {'data': [], 'paging': {'cursors': {'before': 'MTAyMTYxMDkxNzQ3OTI5OTYZD', 'after': 'MjE1NDczNzMyNTY2ODQ3'}}, 'summary': {'total_count': 20, 'can_like': True, 'has_liked': False}}}, {'id': '215473732566847_215895005858053', 'message': 'Garachico la joya de Tenerife \n#Tenerife #VenAlParaiso #Joya #GaleonEnterrado #PiscinasNaturales', 'shares': {'count': 4}, 'from': {'name': 'Turismo Tenerife', 'id': '215473732566847'}, 'created_time': '2018-06-12T09:17:51+0000', 'likes': {'data': [], 'paging': {'cursors': {'before': 'MTAyMTYxMDkxNzQ3OTI5OTYZD', 'after': 'MjE1NDczNzMyNTY2ODQ3'}}, 'summary': {'total_count': 22, 'can_like': True, 'has_liked': False}}}, {'id': '215473732566847_215890599191827', 'created_time': '2018-06-12T08:56:37+0000', 'likes': {'data': [], 'paging': {'cursors': {'before': 'MTAyMTI1MTcwNzMxNDY5MjkZD', 'after': 'MTAyMTI1MTcwNzMxNDY5MjkZD'}}, 'summary': {'total_count': 1, 'can_like': True, 'has_liked': False}}}, {'id': '215473732566847_215611149219772', 'message': 'Visita el pueblo de Candelaria, con la basílica como foco turístico y con las delicias del mar como plato estrella #Candelaria #Tenerife  ...

# %%
# Data extraction

while True:
    try:
        print("Recopilando datos...")
        ### Recupera un post
        for element in posts['data']:
            collection_posts.insert_one(element)
            #### Recupera todos los comentarios de ese post
            this_comment_url = comments_url.replace("{post_id}", element['id'])
            comments = requests.get(this_comment_url, params = params).json()
            # Recorre todos los comentarios hasta que la respuesta esté vacía, que no haya más comentarios
            while ('paging' in comments and 'cursors' in comments['paging'] and 'after' in comments['paging']['cursors']):
                ### Itera a través de todos los comentarios
                for comment in comments['data']:
                    comment['post_id'] = element['id']
                    collection_comments.insert_one(comment)
                comments = requests.get(this_comment_url + '&after=' + comments['paging']['cursors']['after'], params = params).json()
        #### Vamos a la siguiente página en feed
        posts = requests.get(posts['paging']['next']).json()
    except KeyError as e:
        print(e)
        break

print("Datos recopilados")
# Out:
# Recopilando datos...
# 'next'
# Datos recopilados

# %%
# Data pull

posts_data = []
comments_data = []

for doc in collection_posts.find({}):
    if 'message' in doc.keys():
        posts_data.append((doc['message'], doc['created_time'], doc['likes']['summary']['total_count'], doc.get('shares', {'count': 0})['count'], doc['id']))
    else:
        pass
        #print("No message")
        
print(len(posts_data))
    
for comment in collection_comments.find({}):
    if 'message' in comment.keys():
        comments_data.append((comment['message'], comment['created_time'], comment['post_id']))
    else:
        pass

print(len(comments_data))
# Out:
# 11
# 63

# %%
df_posts = pandas.DataFrame(posts_data)
df_posts.columns = ['message', 'created_time', 'likes', 'shares', 'post_id']
df_comments = pandas.DataFrame(comments_data)
df_comments.columns = ['message', 'created_time', 'post_id']

# %%
# Feature extraction

# Funciones

# Limpia comentarios y posts
def preprocess(text):
    # Limpieza básica
    # Limpia de espacios y signos de puntuación, y convierte en minúscula
    text = text.strip()
    text = re.sub(r'[^\w\s]','',text)
    text = text.lower()

    # Divide en tokens
    tokens = nltk.word_tokenize(text) 

    return(tokens,)

# Obtiene los hastags de los mensajes
def get_hashtags(text):
    hashtags = re.findall(r"#(\w+)", text)
    return(hashtags,)

# 
def tag_tokens(preprocessed_tokens):
    pos = nltk.pos_tag(preprocessed_tokens)
    return(pos,)

# 
def get_keywords(tagged_tokens, pos='all'):

    if(pos == 'all'):
        lst_pos = ('NN','JJ','VB')
    elif(pos == 'nouns'):
        lst_pos = 'NN'
    elif(pos == 'verbs'):
        lst_pos = 'VB'
    elif(pos == 'adjectives'):
        lst_pos = 'JJ'
    else:
        lst_pos = ('NN','JJ','VB')

    keywords = [tup[0] for tup in tagged_tokens if tup[1].startswith(lst_pos)]
    return(keywords,)

def get_noun_phrases(tagged_tokens):

    grammar = "NP: {<DT>?<JJ>*<NN>}"
    cp = nltk.RegexpParser(grammar)
    tree = cp.parse(tagged_tokens)

    result = []
    for subtree in tree.subtrees(filter=lambda t: t.label() == 'NP'):
        #Solo tomamos frases, no palabras sueltas
        if(len(subtree.leaves()) > 1):
            outputs = [tup[0] for tup in subtree.leaves()]
            outputs = " ".join(outputs)
            result.append(outputs)
    return(result,)

def execute_pipeline(dataframe):
    print("Entro execute pipeline")
    #Obtener hashtags
    dataframe['hashtags'] = dataframe.apply(lambda x: get_hashtags(x['message']), axis=1)
    print("Paso 1")
    #
    dataframe['preprocessed'] = dataframe.apply(lambda x: preprocess(x['message']), axis=1)
    print("Paso 2")
    #
    dataframe['tagged'] = dataframe.apply(lambda x: tag_tokens(x['preprocessed'][0]), axis=1)
    print("Paso 3") 
    #Extraer palabras clave
    dataframe['keywords'] = dataframe.apply(lambda x: get_keywords(x['tagged'][0], 'all'), axis=1)
    print("Paso 4")
    #
    dataframe['noun_phrases'] = dataframe.apply(lambda x: get_noun_phrases(x['tagged'][0]), axis=1)
    print("Paso 5")
    print("Salgo execute pipeline")
    return(dataframe)

# %%
df_posts = execute_pipeline(df_posts)
# Out:
# Entro execute pipeline
# Paso 1
# Paso 2
# Paso 3
# Paso 4
# Paso 5
# Salgo execute pipeline

# %%
df_comments = execute_pipeline(df_comments)
# Out:
# Entro execute pipeline
# Paso 1
# Paso 2
# Paso 3
# Paso 4
# Paso 5
# Salgo execute pipeline

# %%
#Content analysis
 
def viz_wordcloud(dataframe, column_name, title):
    lst_tokens = list(itertools.chain.from_iterable(dataframe[column_name]))
    lst_p = []
    for phrase in lst_tokens:
        lst_p.extend(phrase)
    lst_phrases = [phrase.replace(" ", "_") for phrase in lst_p]

    CLEANING_LIST = ['el', 'la', 'lo', 'que', 'con', 'del', 'lo','como','una', 'al','su','un','en' ] # Lista con palabras que consideraremos como ruido
    lst_phrases = [phrase for phrase in lst_phrases if not any(spam in phrase.lower() for spam in CLEANING_LIST)] # Quitamos los keywords considerados como ruido
    lst_phrases = [phrase.replace(" ","_") for phrase in lst_phrases if len(phrase) > 1] # Eliminamos los tokens que son de una sola letra
    wordcloud = WordCloud(font_path='./Fonts/Verdana.ttf', background_color="White", max_words=2000, max_font_size=40, random_state=42).generate(" ".join(lst_phrases))

    plt.figure()
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.title(title)
    plt.show
    
def print_verbatims(df, nb_verbatim, keywords):
    verbatims = df[df['message'].str.contains(keywords)]
    for i, text in verbatims.head(nb_verbatim).iterrows():
        print(text['message'])

# %%
viz_wordcloud(df_posts, 'keywords', 'Keywords in posts')
viz_wordcloud(df_comments, 'keywords', 'Keywords in comments')

# %%
viz_wordcloud(df_posts, 'hashtags', 'Hashtags in posts')
viz_wordcloud(df_comments, 'hashtags', 'Hashtags in comments')

# %%
viz_wordcloud(df_posts, 'noun_phrases', 'Noun phrases in posts')
viz_wordcloud(df_comments, 'noun_phrases', 'Noun phrases in comments')

# %%
df_comments['date'] = df_comments['created_time'].apply(pandas.to_datetime)
df_comments_ts = df_comments.set_index(['date'])
df_comments_ts = df_comments_ts['2015-01-01':]

df_posts['date'] = df_posts['created_time'].apply(pandas.to_datetime)
df_posts_ts = df_posts.set_index(['date'])
df_posts_ts = df_posts_ts[:'2015-01-01']
print(df_posts)

#Creamos un data frame que contiene la cantidad promedio de likes y shares por semana
dx = df_posts_ts.resample('D').mean()
dx.index.name = 'date'
dx = dx.reset_index()

print(dx)

#Mostramos el progreso de likes
p = ggplot(dx, aes(x = 'date', y = 'likes')) + geom_line()
p = p + xlab("Date") + ylab("Number of likes") + ggtitle("Facebook Turismo Tenerife Page")
print(p)
#Mostramos el progreso de shares
p = ggplot(dx, aes(x = 'date', y = 'shares')) + geom_line()
p = p + xlab("Date") + ylab("Number of shares") + ggtitle("Facebook Turismo Tenerife Page")
print(p)
# Out:
#                                               message  \
# 0   Recorre la cueva del viento, el tubo volcánico...
# 1   Piérdete en los montes de Anaga  y disfruta de...
# 2   Disfruta de las playas paradisíacas de Los Cri...
# 3   Observa el vasto campo de lava que se extiende...
# 4   Lánzate al mar y navega por sus costas para ob...
# 5   Garachico la joya de Tenerife \n#Tenerife #Ven...
# 6   Visita el pueblo de Candelaria, con la basílic...
# 7   Pasea por historia viva en una de las ciudades...
# 8   Santa Cruz ocio y diversión\n#SC #Tenerife #Ve...
# 9   Ven al Puerto de la Cruz, ciudad costera de Te...
# 10  ¿Quieres descubrir qué hay más allá de las nub...
#
#                 created_time  likes  shares                          post_id  \
# 0   2018-06-12T11:25:54+0000     28      15  215473732566847_215942402519980
# 1   2018-06-12T11:17:37+0000     24       6  215473732566847_215939769186910
# 2   2018-06-12T11:06:06+0000     23       4  215473732566847_215935885853965
# 3   2018-06-12T10:59:00+0000     22       3  215473732566847_215933575854196
# 4   2018-06-12T09:54:46+0000     20       7  215473732566847_215906422523578
# 5   2018-06-12T09:17:51+0000     22       4  215473732566847_215895005858053
# 6   2018-06-11T16:20:14+0000     16       1  215473732566847_215611149219772
# 7   2018-06-11T12:21:08+0000     21       6  215473732566847_215519395895614
# 8   2018-06-11T12:14:11+0000     16       2  215473732566847_215516722562548
# 9   2018-06-11T11:58:35+0000     20       3  215473732566847_215511445896409
# 10  2018-06-11T11:31:48+0000     17       2  215473732566847_215502852563935
#
#                                              hashtags  \
# 0   ([Drago, Tenerife, TuboVolcánico, Icod, Parais...
# 1        ([Anaga, Tenerife, SC, Laurisilva, Bosque],)
# 2   ([Tenerife, Playas, VenAlParaiso, LosCristiano...
# 3   ([Malpais, MontañaGrande, Güimar, Tenerife, Vo...
# 4   ([Tenerife, Paraiso, Gigantes, Delfines, Relax],)
# 5   ([Tenerife, VenAlParaiso, Joya, GaleonEnterrad...
# 6        ([Candelaria, Tenerife, PatronaDeCanarias],)
# 7   ([LaLaguna, Tenerife, PatrimonioDeLaHumanidad,...
# 8                     ([SC, Tenerife, VenAlParaiso],)
# 9   ([PuertodelaCruz, Tenerife, Canarias, LoroParq...
# 10  ([Tenerifelicidad, VenAlParaíso, Tenerife, Pad...
#
#                                          preprocessed  \
# 0   ([recorre, la, cueva, del, viento, el, tubo, v...
# 1   ([piérdete, en, los, montes, de, anaga, y, dis...
# 2   ([disfruta, de, las, playas, paradisíacas, de,...
# 3   ([observa, el, vasto, campo, de, lava, que, se...
# 4   ([lánzate, al, mar, y, navega, por, sus, costa...
# 5   ([garachico, la, joya, de, tenerife, tenerife,...
# 6   ([visita, el, pueblo, de, candelaria, con, la,...
# 7   ([pasea, por, historia, viva, en, una, de, las...
# 8   ([santa, cruz, ocio, y, diversión, sc, tenerif...
# 9   ([ven, al, puerto, de, la, cruz, ciudad, coste...
# 10  ([quieres, descubrir, qué, hay, más, allá, de,...
#
#                                                tagged  \
# 0   ([(recorre, JJ), (la, NN), (cueva, NN), (del, ...
# 1   ([(piérdete, JJ), (en, FW), (los, FW), (montes...
# 2   ([(disfruta, NN), (de, IN), (las, FW), (playas...
# 3   ([(observa, JJ), (el, NN), (vasto, NN), (campo...
# 4   ([(lánzate, NN), (al, NN), (mar, NN), (y, NN),...
# 5   ([(garachico, NN), (la, NN), (joya, NN), (de, ...
# 6   ([(visita, JJ), (el, NN), (pueblo, NN), (de, I...
# 7   ([(pasea, NN), (por, NN), (historia, NN), (viv...
# 8   ([(santa, NN), (cruz, NN), (ocio, IN), (y, NN)...
# 9   ([(ven, RB), (al, JJ), (puerto, NN), (de, IN),...
# 10  ([(quieres, NNS), (descubrir, VBP), (qué, JJ),...
#
#                                              keywords  \
# 0   ([recorre, la, cueva, del, el, tubo, volcánico...
# 1     ([piérdete, tenerife, sc, laurisilva, bosque],)
# 2   ([disfruta, playas, paradisíacas, cristianos, ...
# 3   ([observa, el, vasto, campo, desde, montaña, g...
# 4   ([lánzate, al, mar, y, navega, por, sus, costa...
# 5   ([garachico, la, joya, tenerife, venalparaiso,...
# 6   ([visita, el, pueblo, con, la, basílica, como,...
# 7   ([pasea, por, historia, ciudades, más, cultura...
# 8   ([santa, cruz, y, diversión, sc, tenerife, ven...
# 9   ([al, puerto, ciudad, costera, con, playas, co...
# 10  ([quieres, descubrir, qué, hay, más, allá, nub...
#
#                                          noun_phrases                date
# 0    ([recorre la, el tubo, tenerife tubovolcánico],) 2018-06-12 11:25:54
# 1                                               ([],) 2018-06-12 11:17:37
# 2       ([playas paradisíacas, cristianos tenerife],) 2018-06-12 11:06:06
# 3                                     ([observa el],) 2018-06-12 10:59:00
# 4   ([navega por, una nueva, espectacular acantila... 2018-06-12 09:54:46
# 5                          ([tenerife venalparaiso],) 2018-06-12 09:17:51
# 6                                      ([visita el],) 2018-06-11 16:20:14
# 7                                               ([],) 2018-06-11 12:21:08
# 8                                    ([sc tenerife],) 2018-06-11 12:14:11
# 9             ([al puerto, con playas, otro rincón],) 2018-06-11 11:58:35
# 10  ([qué hay, lugar idílico, venalparaíso tenerif... 2018-06-11 11:31:48
#         date      likes  shares
# 0 2018-06-11  18.000000     2.8
# 1 2018-06-12  23.166667     6.5
# <ggplot: (25188977)>
# <ggplot: (25087385)>

# %%
def max_wordcloud(ts_df_posts, ts_df_comments, columnname, criterium, title):
    mean_week = ts_df_posts.resample('W').mean()
    start_week = (mean_week[criterium].idxmax() - datetime.timedelta(days=7)).strftime('%Y-%m-%d')
    end_week = mean_week[criterium].idxmax().strftime('%Y-%m-%d')
    viz_wordcloud(ts_df_posts[end_week:start_week], columnname, title)
    viz_wordcloud(ts_df_comments[start_week:end_week], columnname, title + ' comments')

max_wordcloud(df_posts_ts, df_comments_ts, 'keywords', 'likes', 'Keywords in maximun likes post')
max_wordcloud(df_posts_ts, df_comments_ts, 'keywords','shares', 'Keywords in maximun shares post')

max_wordcloud(df_posts_ts, df_comments_ts, 'hashtags', 'likes', 'Hashtags in maximun likes post')
max_wordcloud(df_posts_ts, df_comments_ts, 'hashtags','shares', 'Hashtags in maximun shares post')

# %%
url_api = "https://gateway.watsonplatform.net/natural-language-understanding/api"

def get_sentiment(text):
    try:
        natural_language_understanding = NaturalLanguageUnderstandingV1(
            username="209d9a26-cca5-4bef-9690-33f5e8ee66da",
            password="SpWglqCnrHqD",
            version='2018-03-16')
        response = natural_language_understanding.analyze(
            text=text,
            features=Features(
                emotion=EmotionOptions(),
                sentiment=SentimentOptions()))
        
        return json.dumps(response, indent=2)
    except:
        return None

# %%
df_nlu = df_comments
df_nlu['alchemy'] = df_nlu.apply(lambda x: get_sentiment(x['message']), axis=1, reduce=True)

emotions = []
sentiments = []
languages = []

for p in df_nlu['alchemy']:
    if not p == None:
        fichero = json.loads(p)
        languages.append(fichero['language'])
        sentiments.append((fichero['sentiment']['document']['label'], fichero['sentiment']['document']['score']))
        if 'emotion' in fichero.keys():
            emotions.append( fichero['emotion']['document']['emotion'])
        

print(languages)
print(sentiments)
print(emotions)

df_emotions = pandas.DataFrame(emotions)
df_sentiments = pandas.DataFrame(sentiments)
df_sentiments.columns = ['label', 'score']
df_languages = pandas.DataFrame(languages)
df_languages.columns = ['languages']

"""for p in df_nlu['sentiments']:
    if not p == None:
        languages.append(p[0])
        if not p[1] == None:
            emotions.append(p[1])
        sentiments.append(p[2])

df_emotions = pandas.DataFrame(emotions)
df_sentiments = pandas.DataFrame(sentiments)
df_languages = pandas.DataFrame(languages)"""
# Out:
# ['pt', 'fr', 'es', 'es', 'es', 'es', 'es', 'es', 'pt', 'es', 'es', 'es', 'es', 'es', 'es', 'en', 'es', 'en', 'en', 'en', 'en', 'es', 'ru', 'es', 'pt', 'es', 'es', 'es', 'pt', 'es', 'es', 'en', 'es', 'es', 'es', 'es', 'es', 'es', 'es', 'es', 'en', 'es', 'es', 'es', 'es', 'it', 'en', 'pt', 'es', 'es', 'es', 'es', 'en', 'es', 'es', 'es']
# [('negative', -0.803935), ('positive', 0.779312), ('negative', -0.753538), ('positive', 0.593302), ('positive', 0.921677), ('negative', -0.515809), ('positive', 0.977438), ('positive', 0.868392), ('neutral', 0.0), ('positive', 0.913435), ('neutral', 0.0), ('neutral', 0.0), ('neutral', 0.0), ('positive', 0.61108), ('positive', 0.606223), ('positive', 0.920143), ('positive', 0.970212), ('neutral', 0.0), ('positive', 0.87276), ('positive', 0.839355), ('positive', 0.757532), ('neutral', 0.0), ('positive', 0.983887), ('positive', 0.77775), ('positive', 0.926609), ('neutral', 0.0), ('negative', -0.887205), ('positive', 0.858994), ('positive', 0.834426), ('positive', 0.872032), ('positive', 0.740619), ('negative', -0.843923), ('positive', 0.858819), ('positive', 0.975533), ('neutral', 0.0), ('positive', 0.888402), ('positive', 0.90218), ('neutral', 0.0), ('positive', 0.905474), ('positive', 0.801586), ('positive', 0.853072), ('positive', 0.757977), ('neutral', 0.0), ('positive', 0.528149), ('neutral', 0.0), ('positive', 0.789377), ('positive', 0.69774), ('neutral', 0.0), ('negative', -0.445978), ('neutral', 0.0), ('positive', 0.909415), ('positive', 0.792704), ('positive', 0.691814), ('positive', 0.791429), ('neutral', 0.0), ('positive', 0.943656)]
# [{'sadness': 0.02334, 'joy': 0.93372, 'fear': 0.008742, 'disgust': 0.008253, 'anger': 0.017142}, {'sadness': 0.058325, 'joy': 0.40695, 'fear': 0.118817, 'disgust': 0.056482, 'anger': 0.124823}, {'sadness': 0.00823, 'joy': 0.986534, 'fear': 0.000942, 'disgust': 0.001002, 'anger': 0.001685}, {'sadness': 0.029654, 'joy': 0.93219, 'fear': 0.010753, 'disgust': 0.007056, 'anger': 0.013644}, {'sadness': 0.0, 'joy': 0.880435, 'fear': 0.0, 'disgust': 0.0, 'anger': 0.0}, {'sadness': 0.153139, 'joy': 0.058049, 'fear': 0.224223, 'disgust': 0.087499, 'anger': 0.054283}, {'sadness': 0.060609, 'joy': 0.872428, 'fear': 0.018697, 'disgust': 0.008812, 'anger': 0.011583}, {'sadness': 0.00372, 'joy': 0.917367, 'fear': 0.020113, 'disgust': 0.027108, 'anger': 0.031169}, {'sadness': 0.036157, 'joy': 0.93329, 'fear': 0.020814, 'disgust': 0.002681, 'anger': 0.009848}]
# "for p in df_nlu['sentiments']:\n    if not p == None:\n        languages.append(p[0])\n        if not p[1] == None:\n            emotions.append(p[1])\n        sentiments.append(p[2])\n\ndf_emotions = pandas.DataFrame(emotions)\ndf_sentiments = pandas.DataFrame(sentiments)\ndf_languages = pandas.DataFrame(languages)"

# %%
# Mostrando la gráfica de las emociones
df_emotions = df_emotions.apply(pandas.to_numeric, errors='ignore')
print(df_emotions)
df_emotions_means = df_emotions.transpose().apply(numpy.mean, axis=1)
print(df_emotions_means.keys().tolist())


#df_emotions_means.plot(kind='bar', legend=False)
x = df_emotions_means.keys().tolist()
y = df_emotions_means.tolist()
grafica_plotly(x,y,'Emotions')
bar_plotly(x,y,'Emotions')
# Out:
#       anger   disgust      fear       joy   sadness
# 0  0.017142  0.008253  0.008742  0.933720  0.023340
# 1  0.124823  0.056482  0.118817  0.406950  0.058325
# 2  0.001685  0.001002  0.000942  0.986534  0.008230
# 3  0.013644  0.007056  0.010753  0.932190  0.029654
# 4  0.000000  0.000000  0.000000  0.880435  0.000000
# 5  0.054283  0.087499  0.224223  0.058049  0.153139
# 6  0.011583  0.008812  0.018697  0.872428  0.060609
# 7  0.031169  0.027108  0.020113  0.917367  0.003720
# 8  0.009848  0.002681  0.020814  0.933290  0.036157
# ['anger', 'disgust', 'fear', 'joy', 'sadness']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-2a2ec09a4b6c> in <module>()
#       9 x = df_emotions_means.keys().tolist()
#      10 y = df_emotions_means.tolist()
# ---> 11 grafica_plotly(x,y,'Emotions')
#      12 bar_plotly(x,y,'Emotions')
#
# NameError: name 'grafica_plotly' is not defined

# %%
df_languages['languages'].value_counts().plot(kind='bar', title='Language')

# %%
#df_sentiments['label'].value_counts().plot(kind='bar', title='Sentiments')
print(df_sentiments['label'].value_counts())
# Out:
# positive    36
# neutral     14
# negative     6
# Name: label, dtype: int64

# %%
import plotly
import plotly.plotly as py
import plotly.graph_objs as go
plotly.offline.init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
labels = df_sentiments['label'].value_counts().keys().tolist()
values = df_sentiments['label'].value_counts().tolist()

trace = go.Pie(labels=labels, values=values)
plotly.offline.plot([trace], filename='grafica'+'.html')
# Out:
# 'file://D:\\Repositorios\\TFG\\grafica.html'

# %%
plotly.__version__
# Out:
# '2.7.0'

# %%
def grafica_plotly(labels, values, title):
    """trace = go.Pie(labels=labels, values=values)
    plotly.offline.iplot([trace], filename=title)"""
    plotly.offline.init_notebook_mode(connected=True)
    
    fig = {
    'data': [{'labels': labels,
              'values': values,
              'type': 'pie'}],
    'layout': {'title': title}
     }

    plotly.offline.iplot(fig, filename='grafica'+'.html')
    
def grafica_plotly_file(labels, values, title, filename):
    
    fig = {
    'data': [{'labels': labels,
              'values': values,
              'type': 'pie'}],
    'layout': {'title': title}
     }

    plotly.offline.plot(fig, filename=filename + '.html')

# %%
grafica_plotly_file(labels, values, 'Gráfica sentimientos', 'sentiments')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-0bd19b71c7f1> in <module>()
# ----> 1 grafica_plotly_file(labels, values, 'Gráfica sentimientos', 'sentiments')
#
# NameError: name 'labels' is not defined

# %%
labels = df_languages['languages'].value_counts().keys().tolist()
values = df_languages['languages'].value_counts().tolist()
grafica_plotly(labels, values, 'grafica lenguajes')
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="9c0b0fce-c961-4b72-b637-44881ae94e3e" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("9c0b0fce-c961-4b72-b637-44881ae94e3e", [{"labels": ["es", "en", "pt", "it", "fr", "ru"], "values": [39, 9, 5, 1, 1, 1], "type": "pie"}], {"title": "grafica lenguajes"}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
def bar_plotly(x, y, title):
    x = x
    y = y

    trace = go.Bar(
                x=x,
                y=y,)

    data = [trace]
    layout = go.Layout(title=title,height=1 )
    fig = go.Figure(data=data, layout=layout)
    
    plotly.offline.iplot(fig)
    
def bar_plotly_file(x, y, title, filename):
    x = x
    y = y

    trace = go.Bar(
                x=x,
                y=y)

    data = [trace]
    layout = go.Layout(
        title=title,
        )
    fig = go.Figure(data=data, layout=layout)
    
    plotly.offline.plot(fig)

# %%
labels = df_sentiments['label'].value_counts().keys().tolist()
values = df_sentiments['label'].value_counts().tolist()
bar_plotly_file(labels, values, 'Bar Languages', 'label')

# %%
x = ['positive', 'negative']
y = []

trace = go.Bar(
            x=x,
            y=y,)

data = [trace]
layout = go.Layout(title=title,height=1 )
fig = go.Figure(data=data, layout=layout)

plotly.offline.iplot(fig)

# %%
positive = []
negative = []

for i in df_sentiments['score']:
    if i > 0:
        positive.append(i)
    elif i < 0:
        negative.append(i)

# %%
print(positive)
# Out:
# [0.779312, 0.593302, 0.921677, 0.868392, 0.913435, 0.61108, 0.920143, 0.970212, 0.839355, 0.757532, 0.77775, 0.926609, 0.872032, 0.740619, 0.858819, 0.90218, 0.853072, 0.757977, 0.789377, 0.69774, 0.792704, 0.691814, 0.791429]

# %%
median_positive = numpy.median(positive)
median_negative = numpy.median(negative)
print(median_positive)
print(median_negative)
# Out:
# 0.792704
# -0.7787364999999999

# %%
x = ['positive', 'negative']
y = [median_positive, median_negative]
trace = go.Bar(
            x=x,
            y=y,)

data = [trace]
layout = go.Layout(title=title)
fig = go.Figure(data=data, layout=layout)

plotly.offline.iplot(fig)
# Out:
# <div id="c726307a-9176-41b8-9e45-30eda604c5bd" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("c726307a-9176-41b8-9e45-30eda604c5bd", [{"type": "bar", "x": ["positive", "negative"], "y": [0.792704, -0.7787364999999999]}], {"title": "Sentiment score"}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
print(get_hashtags('Hola que tal, #Hola #Adios'))
# Out:
# (['Hola', 'Adios'],)

# %%
print(preprocess('Hola!! que. tal como estas ?, #Hola #Adios'))
# Out:
# (['hola', 'que', 'tal', 'como', 'estas', 'hola', 'adios'],)

# %%
print(tag_tokens(['hola', 'que', 'tal', 'como', 'estas', 'hola', 'adios']))
# Out:
# ([('hola', 'NN'), ('que', 'NN'), ('tal', 'JJ'), ('como', 'NN'), ('estas', 'NNS'), ('hola', 'VBP'), ('adios', 'NNS')],)

# %%
print(get_keywords([('hola', 'NN'), ('que', 'NN'), ('tal', 'JJ'), ('como', 'NN'), ('estas', 'NNS'), ('hola', 'VBP'), ('adios', 'NNS')], 'nouns'))
# Out:
# (['hola', 'que', 'como', 'estas', 'adios'],)

# %%
print(get_noun_phrases_1([('hola', 'NN'), ('que', 'NN'), ('tal', 'JJ'), ('como', 'NN'), ('estas', 'NNS'), ('hola', 'VBP'), ('adios', 'NNS')]))
# Out:
# chunk.RegexpParser with 1 stages:
# RegexpChunkParser with 1 rules:
#        <ChunkRule: '<DT>?<JJ>*<NN>|<DT>?<NN><JJ>*'>
# (S
#   (NP hola/NN)
#   (NP que/NN)
#   (NP tal/JJ como/NN)
#   estas/NNS
#   hola/VBP
#   adios/NNS)
# (['tal como'],)

# %%
def get_noun_phrases_1(tagged_tokens):

    grammar = "NP: {<DT>?<NN><JJ>*|<DT>?<JJ>*<NN>}"
    cp = nltk.RegexpParser(grammar)
    print(cp)
    tree = cp.parse(tagged_tokens)
    print(tree)
    result = []
    for subtree in tree.subtrees(filter=lambda t: t.label() == 'NP'):
        #Solo tomamos frases, no palabras sueltas
        if(len(subtree.leaves()) > 1):
            outputs = [tup[0] for tup in subtree.leaves()]
            outputs = " ".join(outputs)
            result.append(outputs)
    return(result,)
